# %% [markdown]
# # Introduction
#
#
# In this notebook, we implement [The TensorFlow 2 Object Detection Library](https://blog.tensorflow.org/2020/07/tensorflow-2-meets-object-detection-api.html) for training on your own dataset.
#
# We also recommend reading our blog post on [Train TensorFlow 2 Object Detection on custom data](https://blog.roboflow.com/train-a-tensorflow2-object-detection-model/) side by side.
#
# We will take the following steps to implement YOLOv4 on our custom data:
# * Install TensorFlow2 Object Detection Dependencies
# * Download Custom TensorFlow2 Object Detection Dataset
# * Write Custom TensorFlow2 Object Detection Training Configuation
# * Train Custom TensorFlow2 Object Detection Model
# * Export Custom TensorFlow2 Object Detection Weights
# * Use Trained TensorFlow2 Object Detection For Inference on Test Images
#
# When you are done you will have a custom detector that you can use. It will make inference like this:
#
# #### ![Roboflow Workmark](https://i.imgur.com/L0n564N.png)
#
# ### **Reach out for support**
#
# If you run into any hurdles on your own data set or just want to share some cool results in your own domain, [reach out!](https://roboflow.ai)
#
#
#
# #### ![Roboflow Workmark](https://i.imgur.com/WHFqYSJ.png)

# %% [markdown]
# # Install TensorFlow2 Object Detection Dependencies

# %%
import os
import pathlib

# Clone the tensorflow models repository if it doesn't already exist
if "models" in pathlib.Path.cwd().parts:
  while "models" in pathlib.Path.cwd().parts:
    os.chdir('..')
elif not pathlib.Path('models').exists():
  # !git clone --depth 1 https://github.com/tensorflow/models

# %%
# Install the Object Detection API
# %%bash
cd models/research/
protoc object_detection/protos/*.proto --python_out=.
cp object_detection/packages/tf2/setup.py .
python -m pip install .
pip uninstall -y numpy
pip uninstall -y setuptools
pip install setuptools
pip install numpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /content/models/research
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: avro-python3 in /usr/local/lib/python3.9/dist-packages (from object-detection==0.1) (1.10.2)
# Requirement already satisfied: apache-beam in /usr/local/lib/python3.9/dist-packages (from object-detection==0.1) (2.46.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.9/dist-packages (from object-detection==0.1) (8.4.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from object-detection==0.1) (4.9.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from object-detection==0.1) (3.7.1)
# Requirement already satisfied: Cython in /usr/local/lib/python3.9/dist-packages (from object-detection==0.1) (0.29.34)
# Requirement already satisfied: contextlib2 in /usr/local/lib/python3.9/dist-packages (from object-detection==0.1) (0.6.0.post1)
# Requirement already satisfied: tf-slim in /usr/local/lib/python3.9/dist-packages (from object-detection==0.1) (1.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from object-detection==0.1) (1.16.0)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.9/dist-packages (from object-detection==0.1) (2.0.6)
# Requirement already satisfied: lvis in /usr/local/lib/python3.9/dist-packages (from object-detection==0.1) (0.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from object-detection==0.1) (1.10.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from object-detection==0.1) (1.4.4)
# Requirement already satisfied: tf-models-official>=2.5.1 in /usr/local/lib/python3.9/dist-packages (from object-detection==0.1) (2.12.0)
# Requirement already satisfied: tensorflow_io in /usr/local/lib/python3.9/dist-packages (from object-detection==0.1) (0.32.0)
# Requirement already satisfied: keras in /usr/local/lib/python3.9/dist-packages (from object-detection==0.1) (2.12.0)
# Requirement already satisfied: pyparsing==2.4.7 in /usr/local/lib/python3.9/dist-packages (from object-detection==0.1) (2.4.7)
# Requirement already satisfied: sacrebleu<=2.2.0 in /usr/local/lib/python3.9/dist-packages (from object-detection==0.1) (2.2.0)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.9/dist-packages (from sacrebleu<=2.2.0->object-detection==0.1) (0.8.10)
# Requirement already satisfied: regex in /usr/local/lib/python3.9/dist-packages (from sacrebleu<=2.2.0->object-detection==0.1) (2022.10.31)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.9/dist-packages (from sacrebleu<=2.2.0->object-detection==0.1) (2.7.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from sacrebleu<=2.2.0->object-detection==0.1) (1.24.2)
# Requirement already satisfied: colorama in /usr/local/lib/python3.9/dist-packages (from sacrebleu<=2.2.0->object-detection==0.1) (0.4.6)
# Requirement already satisfied: psutil>=5.4.3 in /usr/local/lib/python3.9/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (5.9.4)
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.9/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.1.3)
# Requirement already satisfied: gin-config in /usr/local/lib/python3.9/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.5.0)
# Requirement already satisfied: tensorflow~=2.12.0 in /usr/local/lib/python3.9/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (2.12.0)
# Requirement already satisfied: tensorflow-hub>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.13.0)
# Requirement already satisfied: py-cpuinfo>=3.3.0 in /usr/local/lib/python3.9/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (9.0.0)
# Requirement already satisfied: tensorflow-text~=2.12.0 in /usr/local/lib/python3.9/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (2.12.0)
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.9/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.8.3)
# Requirement already satisfied: tensorflow-model-optimization>=0.4.1 in /usr/local/lib/python3.9/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.7.4)
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.9/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.20.0)
# Requirement already satisfied: immutabledict in /usr/local/lib/python3.9/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (2.2.4)
# Requirement already satisfied: google-api-python-client>=1.6.7 in /usr/local/lib/python3.9/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (2.70.0)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.9/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.7.0.72)
# Requirement already satisfied: pyyaml<6.0,>=5.1 in /usr/local/lib/python3.9/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (5.4.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.9/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.1.97)
# Requirement already satisfied: seqeval in /usr/local/lib/python3.9/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.2.2)
# Requirement already satisfied: kaggle>=1.3.9 in /usr/local/lib/python3.9/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.5.13)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->object-detection==0.1) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->object-detection==0.1) (2.8.2)
# Requirement already satisfied: absl-py>=0.2.2 in /usr/local/lib/python3.9/dist-packages (from tf-slim->object-detection==0.1) (1.4.0)
# Requirement already satisfied: pyarrow<10.0.0,>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from apache-beam->object-detection==0.1) (9.0.0)
# Requirement already satisfied: pymongo<4.0.0,>=3.8.0 in /usr/local/lib/python3.9/dist-packages (from apache-beam->object-detection==0.1) (3.13.0)
# Requirement already satisfied: pydot<2,>=1.2.0 in /usr/local/lib/python3.9/dist-packages (from apache-beam->object-detection==0.1) (1.4.2)
# Requirement already satisfied: objsize<0.7.0,>=0.6.1 in /usr/local/lib/python3.9/dist-packages (from apache-beam->object-detection==0.1) (0.6.1)
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in /usr/local/lib/python3.9/dist-packages (from apache-beam->object-detection==0.1) (2.27.1)
# Requirement already satisfied: grpcio!=1.48.0,<2,>=1.33.1 in /usr/local/lib/python3.9/dist-packages (from apache-beam->object-detection==0.1) (1.53.0)
# Requirement already satisfied: zstandard<1,>=0.18.0 in /usr/local/lib/python3.9/dist-packages (from apache-beam->object-detection==0.1) (0.20.0)
# Requirement already satisfied: httplib2<0.22.0,>=0.8 in /usr/local/lib/python3.9/dist-packages (from apache-beam->object-detection==0.1) (0.21.0)
# Requirement already satisfied: dill<0.3.2,>=0.3.1.1 in /usr/local/lib/python3.9/dist-packages (from apache-beam->object-detection==0.1) (0.3.1.1)
# Requirement already satisfied: cloudpickle~=2.2.1 in /usr/local/lib/python3.9/dist-packages (from apache-beam->object-detection==0.1) (2.2.1)
# Requirement already satisfied: fastavro<2,>=0.23.6 in /usr/local/lib/python3.9/dist-packages (from apache-beam->object-detection==0.1) (1.7.3)
# Requirement already satisfied: protobuf<4,>3.12.2 in /usr/local/lib/python3.9/dist-packages (from apache-beam->object-detection==0.1) (3.20.3)
# Requirement already satisfied: hdfs<3.0.0,>=2.1.0 in /usr/local/lib/python3.9/dist-packages (from apache-beam->object-detection==0.1) (2.7.0)
# Requirement already satisfied: crcmod<2.0,>=1.7 in /usr/local/lib/python3.9/dist-packages (from apache-beam->object-detection==0.1) (1.7)
# Requirement already satisfied: typing-extensions>=3.7.0 in /usr/local/lib/python3.9/dist-packages (from apache-beam->object-detection==0.1) (4.5.0)
# Requirement already satisfied: fasteners<1.0,>=0.3 in /usr/local/lib/python3.9/dist-packages (from apache-beam->object-detection==0.1) (0.18)
# Requirement already satisfied: proto-plus<2,>=1.7.1 in /usr/local/lib/python3.9/dist-packages (from apache-beam->object-detection==0.1) (1.22.2)
# Requirement already satisfied: orjson<4.0 in /usr/local/lib/python3.9/dist-packages (from apache-beam->object-detection==0.1) (3.8.9)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /usr/local/lib/python3.9/dist-packages (from lvis->object-detection==0.1) (4.7.0.72)
# Requirement already satisfied: kiwisolver>=1.1.0 in /usr/local/lib/python3.9/dist-packages (from lvis->object-detection==0.1) (1.4.4)
# Requirement already satisfied: cycler>=0.10.0 in /usr/local/lib/python3.9/dist-packages (from lvis->object-detection==0.1) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->object-detection==0.1) (4.39.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->object-detection==0.1) (1.0.7)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->object-detection==0.1) (5.12.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->object-detection==0.1) (23.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.32.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow_io->object-detection==0.1) (0.32.0)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /usr/local/lib/python3.9/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.1.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.9/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.11.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.9/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (4.1.1)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in /usr/local/lib/python3.9/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.17.1)
# Requirement already satisfied: docopt in /usr/local/lib/python3.9/dist-packages (from hdfs<3.0.0,>=2.1.0->apache-beam->object-detection==0.1) (0.6.2)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->object-detection==0.1) (3.15.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.9/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.26.15)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.9/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (8.0.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (4.65.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.9/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (2.0.12)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (2.12.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (1.6.3)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (1.14.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (2.2.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.9/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (2.12.1)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (0.4.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (23.3.3)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (16.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (67.6.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.9/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (3.3.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (3.8.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (0.2.0)
# Collecting numpy>=1.17
#   Using cached numpy-1.23.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.9/dist-packages (from tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (0.4.7)
# Requirement already satisfied: dm-tree~=0.1.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow-model-optimization>=0.4.1->tf-models-official>=2.5.1->object-detection==0.1) (0.1.8)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.9/dist-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (0.2.8)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.9/dist-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (0.4.8)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.9/dist-packages (from seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.2.2)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.9/dist-packages (from tensorflow-addons->tf-models-official>=2.5.1->object-detection==0.1) (2.13.3)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (8.1.3)
# Requirement already satisfied: promise in /usr/local/lib/python3.9/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (2.3)
# Requirement already satisfied: toml in /usr/local/lib/python3.9/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (0.10.2)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.9/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (1.13.0)
# Requirement already satisfied: etils[enp,epath]>=0.9.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (1.1.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.9/dist-packages (from astunparse>=1.6.0->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (0.40.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.9/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.59.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (5.3.0)
# Requirement already satisfied: ml-dtypes>=0.0.3 in /usr/local/lib/python3.9/dist-packages (from jax>=0.3.15->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (0.0.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.1.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (3.4.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (2.2.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (0.7.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.9/dist-packages (from python-slugify->kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (6.1.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.9/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (2.1.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official>=2.5.1->object-detection==0.1) (3.2.2)
# Building wheels for collected packages: object-detection
#   Building wheel for object-detection (setup.py): started
#   Building wheel for object-detection (setup.py): finished with status 'done'
#   Created wheel for object-detection: filename=object_detection-0.1-py3-none-any.whl size=1697012 sha256=683b4c7718b865e5d26099d4a448c419abd003c80e58e52f5984966adc23bdca
#   Stored in directory: /tmp/pip-ephem-wheel-cache-59syok84/wheels/1d/d6/23/8af3ea45a1048e13ebe55b2675eecc8eb39c9af79b37e078ae
# Successfully built object-detection
# Installing collected packages: numpy, object-detection
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.2
#     Uninstalling numpy-1.24.2:
#       Successfully uninstalled numpy-1.24.2
#   Attempting uninstall: object-detection
#     Found existing installation: object-detection 0.1
#     Uninstalling object-detection-0.1:
#       Successfully uninstalled object-detection-0.1
# Successfully installed numpy-1.23.5 object-detection-0.1
# Found existing installation: numpy 1.23.5
# Uninstalling numpy-1.23.5:
#   Successfully uninstalled numpy-1.23.5
# Found existing installation: setuptools 67.6.1
# Uninstalling setuptools-67.6.1:
#   Successfully uninstalled setuptools-67.6.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting setuptools
#   Downloading setuptools-67.6.1-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 53.4 MB/s eta 0:00:00
# Installing collected packages: setuptools
# Successfully installed setuptools-67.6.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting numpy
#   Using cached numpy-1.24.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
# Installing collected packages: numpy
# Successfully installed numpy-1.24.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.1.9 requires numpy>=1.15.0, which is not installed.
# tensorflow 2.12.0 requires numpy<1.24,>=1.22, which is not installed.
# tensorboard 2.12.1 requires numpy>=1.12.0, which is not installed.
# spacy 3.5.1 requires numpy>=1.15.0, which is not installed.
# pytensor 2.10.1 requires numpy>=1.17.0, which is not installed.
# pymc 5.1.2 requires numpy>=1.15.0, which is not installed.
# pandas-gbq 0.17.9 requires numpy>=1.16.6, which is not installed.
# numba 0.56.4 requires numpy<1.24,>=1.18, which is not installed.
# mlxtend 0.14.0 requires numpy>=1.10.4, which is not installed.
# librosa 0.10.0.post2 requires numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3, which is not installed.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# holoviews 1.15.4 requires numpy>=1.0, which is not installed.
# dopamine-rl 4.0.6 requires numpy>=1.16.4, which is not installed.
# datascience 0.17.6 requires numpy, which is not installed.
# cvxpy 1.3.1 requires numpy>=1.15, which is not installed.
# cufflinks 0.17.3 requires numpy>=1.9.2, which is not installed.
# arviz 0.15.1 requires numpy>=1.20.0, which is not installed.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.12.0 requires numpy<1.24,>=1.22, but you have numpy 1.24.2 which is incompatible.
# numba 0.56.4 requires numpy<1.24,>=1.18, but you have numpy 1.24.2 which is incompatible.

# %%
import matplotlib
import matplotlib.pyplot as plt

import os
import random
import io
import imageio
import glob
import scipy.misc
import numpy as np
from six import BytesIO
from PIL import Image, ImageDraw, ImageFont
from IPython.display import display, Javascript
from IPython.display import Image as IPyImage

import tensorflow as tf

from object_detection.utils import label_map_util
from object_detection.utils import config_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.utils import colab_utils
from object_detection.builders import model_builder

# %matplotlib inline
# Out:
# /usr/local/lib/python3.9/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
#run model builder test
# !python /content/models/research/object_detection/builders/model_builder_tf2_test.py
# Out:
# 2023-04-09 05:08:40.181626: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.9/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# Running tests under Python 3.9.16: /usr/bin/python3
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_deepmac
# 2023-04-09 05:08:45.841288: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:45.914048 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:45.920157 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:45.922443 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:45.925570 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:45.932191 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:45.934710 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:45.938320 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:45.940646 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:45.944430 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:45.946755 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:45.949216 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:45.952833 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:45.955270 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:45.959506 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:45.961720 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:45.966051 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:45.968289 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:45.971854 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.112632 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.115485 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.119042 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.121340 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.126408 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.129122 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.133244 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.135630 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.139440 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.141732 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.144399 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.147955 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.150198 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.154690 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.156920 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.160346 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.162628 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.166551 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.168908 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.171444 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.175197 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.177514 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.181750 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.184225 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.187910 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.190479 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.194395 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.197446 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.200510 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.204207 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.206761 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.210423 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.212686 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.216943 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.219176 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.222625 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.225465 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.228998 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.231233 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.235067 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.237373 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.242903 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.245326 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.247702 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.253538 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.255891 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.259308 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.261613 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.265898 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.268211 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.271804 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.274350 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.278573 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.280874 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.284523 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.286844 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.289276 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.293487 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.295797 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.300279 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.304063 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.308593 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.313529 140252618893120 model_builder.py:1112] Building experimental DeepMAC meta-arch. Some features may be omitted.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.354903 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.358351 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.360943 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.363559 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.368833 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.371521 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.375561 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.379288 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.383795 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.386546 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.389461 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.394012 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# W0409 05:08:46.396633 140252618893120 batch_normalization.py:1426] `tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# ...
# I0409 05:09:18.970379 140252618893120 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b5
# I0409 05:09:18.970535 140252618893120 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 288
# I0409 05:09:18.970610 140252618893120 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 7
# I0409 05:09:18.972389 140252618893120 efficientnet_model.py:143] round_filter input=32 output=48
# I0409 05:09:18.991516 140252618893120 efficientnet_model.py:143] round_filter input=32 output=48
# I0409 05:09:18.991637 140252618893120 efficientnet_model.py:143] round_filter input=16 output=24
# I0409 05:09:19.217712 140252618893120 efficientnet_model.py:143] round_filter input=16 output=24
# I0409 05:09:19.217892 140252618893120 efficientnet_model.py:143] round_filter input=24 output=40
# I0409 05:09:19.666954 140252618893120 efficientnet_model.py:143] round_filter input=24 output=40
# I0409 05:09:19.667136 140252618893120 efficientnet_model.py:143] round_filter input=40 output=64
# I0409 05:09:20.128028 140252618893120 efficientnet_model.py:143] round_filter input=40 output=64
# I0409 05:09:20.128196 140252618893120 efficientnet_model.py:143] round_filter input=80 output=128
# I0409 05:09:20.803397 140252618893120 efficientnet_model.py:143] round_filter input=80 output=128
# I0409 05:09:20.803581 140252618893120 efficientnet_model.py:143] round_filter input=112 output=176
# I0409 05:09:21.460588 140252618893120 efficientnet_model.py:143] round_filter input=112 output=176
# I0409 05:09:21.460751 140252618893120 efficientnet_model.py:143] round_filter input=192 output=304
# I0409 05:09:22.297955 140252618893120 efficientnet_model.py:143] round_filter input=192 output=304
# I0409 05:09:22.298120 140252618893120 efficientnet_model.py:143] round_filter input=320 output=512
# I0409 05:09:22.585296 140252618893120 efficientnet_model.py:143] round_filter input=1280 output=2048
# I0409 05:09:22.630833 140252618893120 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.6, depth_coefficient=2.2, resolution=456, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0409 05:09:22.708013 140252618893120 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b6
# I0409 05:09:22.708150 140252618893120 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 384
# I0409 05:09:22.708218 140252618893120 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 8
# I0409 05:09:22.709857 140252618893120 efficientnet_model.py:143] round_filter input=32 output=56
# I0409 05:09:22.729258 140252618893120 efficientnet_model.py:143] round_filter input=32 output=56
# I0409 05:09:22.729371 140252618893120 efficientnet_model.py:143] round_filter input=16 output=32
# I0409 05:09:22.948623 140252618893120 efficientnet_model.py:143] round_filter input=16 output=32
# I0409 05:09:22.948810 140252618893120 efficientnet_model.py:143] round_filter input=24 output=40
# I0409 05:09:23.496391 140252618893120 efficientnet_model.py:143] round_filter input=24 output=40
# I0409 05:09:23.496571 140252618893120 efficientnet_model.py:143] round_filter input=40 output=72
# I0409 05:09:24.055361 140252618893120 efficientnet_model.py:143] round_filter input=40 output=72
# I0409 05:09:24.055535 140252618893120 efficientnet_model.py:143] round_filter input=80 output=144
# I0409 05:09:24.793000 140252618893120 efficientnet_model.py:143] round_filter input=80 output=144
# I0409 05:09:24.793174 140252618893120 efficientnet_model.py:143] round_filter input=112 output=200
# I0409 05:09:25.827414 140252618893120 efficientnet_model.py:143] round_filter input=112 output=200
# I0409 05:09:25.827606 140252618893120 efficientnet_model.py:143] round_filter input=192 output=344
# I0409 05:09:26.865628 140252618893120 efficientnet_model.py:143] round_filter input=192 output=344
# I0409 05:09:26.865803 140252618893120 efficientnet_model.py:143] round_filter input=320 output=576
# I0409 05:09:27.508018 140252618893120 efficientnet_model.py:143] round_filter input=1280 output=2304
# I0409 05:09:27.563291 140252618893120 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.8, depth_coefficient=2.6, resolution=528, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0409 05:09:27.724024 140252618893120 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b7
# I0409 05:09:27.724220 140252618893120 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 384
# I0409 05:09:27.724296 140252618893120 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 8
# I0409 05:09:27.726957 140252618893120 efficientnet_model.py:143] round_filter input=32 output=64
# I0409 05:09:27.759352 140252618893120 efficientnet_model.py:143] round_filter input=32 output=64
# I0409 05:09:27.762912 140252618893120 efficientnet_model.py:143] round_filter input=16 output=32
# I0409 05:09:28.174539 140252618893120 efficientnet_model.py:143] round_filter input=16 output=32
# I0409 05:09:28.174736 140252618893120 efficientnet_model.py:143] round_filter input=24 output=48
# I0409 05:09:29.049088 140252618893120 efficientnet_model.py:143] round_filter input=24 output=48
# I0409 05:09:29.049276 140252618893120 efficientnet_model.py:143] round_filter input=40 output=80
# I0409 05:09:30.004749 140252618893120 efficientnet_model.py:143] round_filter input=40 output=80
# I0409 05:09:30.004974 140252618893120 efficientnet_model.py:143] round_filter input=80 output=160
# I0409 05:09:31.363073 140252618893120 efficientnet_model.py:143] round_filter input=80 output=160
# I0409 05:09:31.363279 140252618893120 efficientnet_model.py:143] round_filter input=112 output=224
# I0409 05:09:32.758259 140252618893120 efficientnet_model.py:143] round_filter input=112 output=224
# I0409 05:09:32.758471 140252618893120 efficientnet_model.py:143] round_filter input=192 output=384
# I0409 05:09:34.499608 140252618893120 efficientnet_model.py:143] round_filter input=192 output=384
# I0409 05:09:34.499834 140252618893120 efficientnet_model.py:143] round_filter input=320 output=640
# I0409 05:09:35.044431 140252618893120 efficientnet_model.py:143] round_filter input=1280 output=2560
# I0409 05:09:35.083144 140252618893120 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=2.0, depth_coefficient=3.1, resolution=600, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 41.49s
# I0409 05:09:35.188559 140252618893120 test_util.py:2467] time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 41.49s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# [ RUN      ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# I0409 05:09:35.217992 140252618893120 test_util.py:2467] time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# [ RUN      ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# I0409 05:09:35.219839 140252618893120 test_util.py:2467] time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# [ RUN      ] ModelBuilderTF2Test.test_invalid_model_config_proto
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# I0409 05:09:35.220341 140252618893120 test_util.py:2467] time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_model_config_proto
# [ RUN      ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# I0409 05:09:35.221777 140252618893120 test_util.py:2467] time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# [ RUN      ] ModelBuilderTF2Test.test_session
# [  SKIPPED ] ModelBuilderTF2Test.test_session
# [ RUN      ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# I0409 05:09:35.223068 140252618893120 test_util.py:2467] time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# [ RUN      ] ModelBuilderTF2Test.test_unknown_meta_architecture
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# I0409 05:09:35.223475 140252618893120 test_util.py:2467] time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_meta_architecture
# [ RUN      ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# I0409 05:09:35.224427 140252618893120 test_util.py:2467] time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# ----------------------------------------------------------------------
# Ran 24 tests in 52.084s
#
# OK (skipped=1)

# %%
def load_image_into_numpy_array(path):
  """Load an image from file into a numpy array.

  Puts image into numpy array to feed into tensorflow graph.
  Note that by convention we put it into a numpy array with shape
  (height, width, channels), where channels=3 for RGB.

  Args:
    path: a file path.

  Returns:
    uint8 numpy array with shape (img_height, img_width, 3)
  """
  img_data = tf.io.gfile.GFile(path, 'rb').read()
  image = Image.open(BytesIO(img_data))
  (im_width, im_height) = image.size
  return np.array(image.getdata()).reshape(
      (im_height, im_width, 3)).astype(np.uint8)

def plot_detections(image_np,
                    boxes,
                    classes,
                    scores,
                    category_index,
                    figsize=(12, 16),
                    image_name=None):
  """Wrapper function to visualize detections.

  Args:
    image_np: uint8 numpy array with shape (img_height, img_width, 3)
    boxes: a numpy array of shape [N, 4]
    classes: a numpy array of shape [N]. Note that class indices are 1-based,
      and match the keys in the label map.
    scores: a numpy array of shape [N] or None.  If scores=None, then
      this function assumes that the boxes to be plotted are groundtruth
      boxes and plot all boxes as black with no classes or scores.
    category_index: a dict containing category dictionaries (each holding
      category index `id` and category name `name`) keyed by category indices.
    figsize: size for the figure.
    image_name: a name for the image file.
  """
  image_np_with_annotations = image_np.copy()
  viz_utils.visualize_boxes_and_labels_on_image_array(
      image_np_with_annotations,
      boxes,
      classes,
      scores,
      category_index,
      use_normalized_coordinates=True,
      min_score_thresh=0.8)
  if image_name:
    plt.imsave(image_name, image_np_with_annotations)
  else:
    plt.imshow(image_np_with_annotations)

# %% [markdown]
# # Prepare Tensorflow 2 Object Detection Training Data
#
#
# Roboflow automatically creates our TFRecord and label_map files that we need!
#
# **Generating your own TFRecords the only step you need to change for your own custom dataset.**
#
# Because we need one TFRecord file for our training data, and one TFRecord file for our test data, we'll create two separate datasets in Roboflow and generate one set of TFRecords for each.
#
# To create a dataset in Roboflow and generate TFRecords, follow [this step-by-step guide](https://blog.roboflow.ai/getting-started-with-roboflow/).

# %% [markdown]
# ![](https://i.imgur.com/ZwMdcbY.png)

# %%
#follow the link below to get your download code from from Roboflow
# !pip install -q roboflow

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="BbWC5ppO2riGs4B0iAvf", model_format="tfrecord", notebook="roboflow-tf2-od")
project = rf.workspace("thesis-vfvpg").project("knives-n-guns-april")
dataset = project.version(1).download("tfrecord")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Knifes-and-guns-4 to tfrecord: 100% [378666794 / 378666794] bytes
# Extracting Dataset Version Zip to Knifes-and-guns-4 in tfrecord:: 100%|██████████| 11/11 [00:01<00:00,  6.42it/s]

# %%
# NOTE: Update these TFRecord names from "cells" and "cells_label_map" to your files!
test_record_fname = dataset.location + '/test/knifes-guns.tfrecord'
train_record_fname = dataset.location + '/train/knifes-guns.tfrecord'
label_map_pbtxt_fname = dataset.location + '/train/knifes-guns_label_map.pbtxt'

# %% [markdown]
# # Configure Custom TensorFlow2 Object Detection Training Configuration
#
#
#
#
# > In this section you can specify any model in the [TF2 OD model zoo](https://github.com/tensorflow/models/blob/master/research/object_detection/g3doc/tf2_detection_zoo.md) and set up your training configuration.

# %%
##change chosen model to deploy different models available in the TF2 object detection zoo
MODELS_CONFIG = {
    'efficientdet-d0': {
        'model_name': 'efficientdet_d0_coco17_tpu-32',
        'base_pipeline_file': 'ssd_efficientdet_d0_512x512_coco17_tpu-8.config',
        'pretrained_checkpoint': 'efficientdet_d0_coco17_tpu-32.tar.gz',
        'batch_size': 16
    },
    'efficientdet-d1': {
        'model_name': 'efficientdet_d1_coco17_tpu-32',
        'base_pipeline_file': 'ssd_efficientdet_d1_640x640_coco17_tpu-8.config',
        'pretrained_checkpoint': 'efficientdet_d1_coco17_tpu-32.tar.gz',
        'batch_size': 16
    },
    'efficientdet-d2': {
        'model_name': 'efficientdet_d2_coco17_tpu-32',
        'base_pipeline_file': 'ssd_efficientdet_d2_768x768_coco17_tpu-8.config',
        'pretrained_checkpoint': 'efficientdet_d2_coco17_tpu-32.tar.gz',
        'batch_size': 16
    },
        'efficientdet-d3': {
        'model_name': 'efficientdet_d3_coco17_tpu-32',
        'base_pipeline_file': 'ssd_efficientdet_d3_896x896_coco17_tpu-32.config',
        'pretrained_checkpoint': 'efficientdet_d3_coco17_tpu-32.tar.gz',
        'batch_size': 16
    }
}

#in this tutorial we implement the lightweight, smallest state of the art efficientdet model
#if you want to scale up tot larger efficientdet models you will likely need more compute!
chosen_model = 'efficientdet-d0'

num_steps = 40000 #The more steps, the longer the training. Increase if your loss function is still decreasing and validation metrics are increasing. 
num_eval_steps = 500 #Perform evaluation after so many steps

model_name = MODELS_CONFIG[chosen_model]['model_name']
pretrained_checkpoint = MODELS_CONFIG[chosen_model]['pretrained_checkpoint']
base_pipeline_file = MODELS_CONFIG[chosen_model]['base_pipeline_file']
batch_size = MODELS_CONFIG[chosen_model]['batch_size'] #if you can fit a large batch in memory, it may speed up your training

# %%
#download pretrained weights
# %mkdir /content/models/research/deploy/
# %cd /content/models/research/deploy/
import tarfile
download_tar = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/' + pretrained_checkpoint

# !wget {download_tar}
tar = tarfile.open(pretrained_checkpoint)
tar.extractall()
tar.close()
# Out:
# /content/models/research/deploy
# --2023-04-09 05:13:48--  http://download.tensorflow.org/models/object_detection/tf2/20200711/efficientdet_d0_coco17_tpu-32.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 74.125.68.128, 2404:6800:4003:c03::80
# Connecting to download.tensorflow.org (download.tensorflow.org)|74.125.68.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30736482 (29M) [application/x-tar]
# Saving to: ‘efficientdet_d0_coco17_tpu-32.tar.gz’
#
# efficientdet_d0_coc 100%[===================>]  29.31M  25.8MB/s    in 1.1s
#
# 2023-04-09 05:13:50 (25.8 MB/s) - ‘efficientdet_d0_coco17_tpu-32.tar.gz’ saved [30736482/30736482]

# %%
#download base training configuration file
# %cd /content/models/research/deploy
download_config = 'https://raw.githubusercontent.com/tensorflow/models/master/research/object_detection/configs/tf2/' + base_pipeline_file
# !wget {download_config}
# Out:
# /content/models/research/deploy
# --2023-04-09 05:13:51--  https://raw.githubusercontent.com/tensorflow/models/master/research/object_detection/configs/tf2/ssd_efficientdet_d0_512x512_coco17_tpu-8.config
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4630 (4.5K) [text/plain]
# Saving to: ‘ssd_efficientdet_d0_512x512_coco17_tpu-8.config’
#
# ssd_efficientdet_d0 100%[===================>]   4.52K  --.-KB/s    in 0s
#
# 2023-04-09 05:13:51 (51.2 MB/s) - ‘ssd_efficientdet_d0_512x512_coco17_tpu-8.config’ saved [4630/4630]

# %%
#prepare
pipeline_fname = '/content/models/research/deploy/' + base_pipeline_file
fine_tune_checkpoint = '/content/models/research/deploy/' + model_name + '/checkpoint/ckpt-0'

def get_num_classes(pbtxt_fname):
    from object_detection.utils import label_map_util
    label_map = label_map_util.load_labelmap(pbtxt_fname)
    categories = label_map_util.convert_label_map_to_categories(
        label_map, max_num_classes=90, use_display_name=True)
    category_index = label_map_util.create_category_index(categories)
    return len(category_index.keys())
num_classes = get_num_classes(label_map_pbtxt_fname)

# %%
label_map_pbtxt_fname
# Out:
# '/content/Knifes-and-guns-4/train/knifes-guns_label_map.pbtxt'

# %%
#write custom configuration file by slotting our dataset, model checkpoint, and training parameters into the base pipeline file

import re

# %cd /content/models/research/deploy
print('writing custom configuration file')

with open(pipeline_fname) as f:
    s = f.read()
with open('pipeline_file.config', 'w') as f:
    
    # fine_tune_checkpoint
    s = re.sub('fine_tune_checkpoint: ".*?"',
               'fine_tune_checkpoint: "{}"'.format(fine_tune_checkpoint), s)
    
    # tfrecord files train and test.
    s = re.sub(
        '(input_path: ".*?)(PATH_TO_BE_CONFIGURED/train)(.*?")', 'input_path: "{}"'.format(train_record_fname), s)
    s = re.sub(
        '(input_path: ".*?)(PATH_TO_BE_CONFIGURED/val)(.*?")', 'input_path: "{}"'.format(test_record_fname), s)

    # label_map_path
    s = re.sub(
        'label_map_path: ".*?"', 'label_map_path: "{}"'.format(label_map_pbtxt_fname), s)

    # Set training batch_size.
    s = re.sub('batch_size: [0-9]+',
               'batch_size: {}'.format(batch_size), s)

    # Set training steps, num_steps
    s = re.sub('num_steps: [0-9]+',
               'num_steps: {}'.format(num_steps), s)
    
    # Set number of classes num_classes.
    s = re.sub('num_classes: [0-9]+',
               'num_classes: {}'.format(num_classes), s)
    
    #fine-tune checkpoint type
    s = re.sub(
        'fine_tune_checkpoint_type: "classification"', 'fine_tune_checkpoint_type: "{}"'.format('detection'), s)
        
    f.write(s)
# Out:
# /content/models/research/deploy
# writing custom configuration file

# %%
# %cat /content/models/research/deploy/pipeline_file.config
# Out:
#  # SSD with EfficientNet-b0 + BiFPN feature extractor,
# # shared box predictor and focal loss (a.k.a EfficientDet-d0).
# # See EfficientDet, Tan et al, https://arxiv.org/abs/1911.09070
# # See Lin et al, https://arxiv.org/abs/1708.02002
# # Trained on COCO, initialized from an EfficientNet-b0 checkpoint.
# #
# # Train on TPU-8
#
# model {
#   ssd {
#     inplace_batchnorm_update: true
#     freeze_batchnorm: false
#     num_classes: 2
#     add_background_class: false
#     box_coder {
#       faster_rcnn_box_coder {
#         y_scale: 10.0
#         x_scale: 10.0
#         height_scale: 5.0
#         width_scale: 5.0
#       }
#     }
#     matcher {
#       argmax_matcher {
#         matched_threshold: 0.5
#         unmatched_threshold: 0.5
#         ignore_thresholds: false
#         negatives_lower_than_unmatched: true
#         force_match_for_each_row: true
#         use_matmul_gather: true
#       }
#     }
#     similarity_calculator {
#       iou_similarity {
#       }
#     }
#     encode_background_as_zeros: true
#     anchor_generator {
#       multiscale_anchor_generator {
#         min_level: 3
#         max_level: 7
#         anchor_scale: 4.0
#         aspect_ratios: [1.0, 2.0, 0.5]
#         scales_per_octave: 3
#       }
#     }
#     image_resizer {
#       keep_aspect_ratio_resizer {
#         min_dimension: 512
#         max_dimension: 512
#         pad_to_max_dimension: true
#         }
#     }
#     box_predictor {
#       weight_shared_convolutional_box_predictor {
#         depth: 64
#         class_prediction_bias_init: -4.6
#         conv_hyperparams {
#           force_use_bias: true
#           activation: SWISH
#           regularizer {
#             l2_regularizer {
#               weight: 0.00004
#             }
#           }
#           initializer {
#             random_normal_initializer {
#               stddev: 0.01
#               mean: 0.0
#             }
#           }
#           batch_norm {
#             scale: true
#             decay: 0.99
#             epsilon: 0.001
#           }
#         }
#         num_layers_before_predictor: 3
#         kernel_size: 3
#         use_depthwise: true
#       }
#     }
#     feature_extractor {
#       type: 'ssd_efficientnet-b0_bifpn_keras'
#       bifpn {
#         min_level: 3
#         max_level: 7
#         num_iterations: 3
#         num_filters: 64
#       }
#       conv_hyperparams {
#         force_use_bias: true
#         activation: SWISH
#         regularizer {
#           l2_regularizer {
#             weight: 0.00004
#           }
#         }
#         initializer {
#           truncated_normal_initializer {
#             stddev: 0.03
#             mean: 0.0
#           }
#         }
#         batch_norm {
#           scale: true,
#           decay: 0.99,
#           epsilon: 0.001,
#         }
#       }
#     }
#     loss {
#       classification_loss {
#         weighted_sigmoid_focal {
#           alpha: 0.25
#           gamma: 1.5
#         }
#       }
#       localization_loss {
#         weighted_smooth_l1 {
#         }
#       }
#       classification_weight: 1.0
#       localization_weight: 1.0
#     }
#     normalize_loss_by_num_matches: true
#     normalize_loc_loss_by_codesize: true
#     post_processing {
#       batch_non_max_suppression {
#         score_threshold: 1e-8
#         iou_threshold: 0.5
#         max_detections_per_class: 100
#         max_total_detections: 100
#       }
#       score_converter: SIGMOID
#     }
#   }
# }
#
# train_config: {
#   fine_tune_checkpoint: "/content/models/research/deploy/efficientdet_d0_coco17_tpu-32/checkpoint/ckpt-0"
#   fine_tune_checkpoint_version: V2
#   fine_tune_checkpoint_type: "detection"
#   batch_size: 16
#   sync_replicas: true
#   startup_delay_steps: 0
#   replicas_to_aggregate: 8
#   use_bfloat16: true
#   num_steps: 40000
#   data_augmentation_options {
#     random_horizontal_flip {
#     }
#   }
#   data_augmentation_options {
#     random_scale_crop_and_pad_to_square {
#       output_size: 512
#       scale_min: 0.1
#       scale_max: 2.0
#     }
#   }
#   optimizer {
#     momentum_optimizer: {
#       learning_rate: {
#         cosine_decay_learning_rate {
#           learning_rate_base: 8e-2
#           total_steps: 300000
#           warmup_learning_rate: .001
#           warmup_steps: 2500
#         }
#       }
#       momentum_optimizer_value: 0.9
#     }
#     use_moving_average: false
#   }
#   max_number_of_boxes: 100
#   unpad_groundtruth_tensors: false
# }
#
# train_input_reader: {
#   label_map_path: "/content/Knifes-and-guns-4/train/knifes-guns_label_map.pbtxt"
#   tf_record_input_reader {
#     input_path: "/content/Knifes-and-guns-4/train/knifes-guns.tfrecord"
#   }
# }
#
# eval_config: {
#   metrics_set: "coco_detection_metrics"
#   use_moving_averages: false
#   batch_size: 16;
# }
#
# eval_input_reader: {
#   label_map_path: "/content/Knifes-and-guns-4/train/knifes-guns_label_map.pbtxt"
#   shuffle: false
#   num_epochs: 1
#   tf_record_input_reader {
#     input_path: "/content/Knifes-and-guns-4/test/knifes-guns.tfrecord"
#   }
# }

# %%
pipeline_file = '/content/models/research/deploy/pipeline_file.config'
model_dir = '/content/training/'

# %% [markdown]
# # Train Custom TF2 Object Detector
#
# * pipeline_file: defined above in writing custom training configuration
# * model_dir: the location tensorboard logs and saved model checkpoints will save to
# * num_train_steps: how long to train for
# * num_eval_steps: perform eval on validation set after this many steps

# %%
# !python /content/models/research/object_detection/model_main_tf2.py \
    --pipeline_config_path={pipeline_file} \
    --model_dir={model_dir} \
    --alsologtostderr \
    --num_train_steps={num_steps} \
    --sample_1_of_n_eval_examples=1 \
    --num_eval_steps={num_eval_steps}
# Out:
# 2023-04-09 05:22:52.999540: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.9/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# 2023-04-09 05:22:56.379432: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I0409 05:22:56.401641 140609851844416 mirrored_strategy.py:374] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: 40000
# I0409 05:22:56.404878 140609851844416 config_util.py:552] Maybe overwriting train_steps: 40000
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0409 05:22:56.405031 140609851844416 config_util.py:552] Maybe overwriting use_bfloat16: False
# I0409 05:22:56.415728 140609851844416 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b0
# I0409 05:22:56.415841 140609851844416 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 64
# I0409 05:22:56.415904 140609851844416 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 3
# I0409 05:22:56.420583 140609851844416 efficientnet_model.py:143] round_filter input=32 output=32
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0409 05:22:56.604470 140609851844416 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0409 05:22:56.608381 140609851844416 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0409 05:22:56.615087 140609851844416 efficientnet_model.py:143] round_filter input=32 output=32
# I0409 05:22:56.615189 140609851844416 efficientnet_model.py:143] round_filter input=16 output=16
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0409 05:22:56.638383 140609851844416 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0409 05:22:56.641488 140609851844416 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0409 05:22:56.714363 140609851844416 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0409 05:22:56.717354 140609851844416 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0409 05:22:56.722929 140609851844416 efficientnet_model.py:143] round_filter input=16 output=16
# I0409 05:22:56.723024 140609851844416 efficientnet_model.py:143] round_filter input=24 output=24
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0409 05:22:56.745297 140609851844416 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0409 05:22:56.748327 140609851844416 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0409 05:22:56.774255 140609851844416 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0409 05:22:56.777227 140609851844416 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0409 05:22:56.994772 140609851844416 efficientnet_model.py:143] round_filter input=24 output=24
# I0409 05:22:56.994945 140609851844416 efficientnet_model.py:143] round_filter input=40 output=40
# I0409 05:22:57.262911 140609851844416 efficientnet_model.py:143] round_filter input=40 output=40
# I0409 05:22:57.263072 140609851844416 efficientnet_model.py:143] round_filter input=80 output=80
# I0409 05:22:57.654692 140609851844416 efficientnet_model.py:143] round_filter input=80 output=80
# I0409 05:22:57.654860 140609851844416 efficientnet_model.py:143] round_filter input=112 output=112
# I0409 05:22:58.032419 140609851844416 efficientnet_model.py:143] round_filter input=112 output=112
# I0409 05:22:58.032576 140609851844416 efficientnet_model.py:143] round_filter input=192 output=192
# I0409 05:22:58.533911 140609851844416 efficientnet_model.py:143] round_filter input=192 output=192
# I0409 05:22:58.534078 140609851844416 efficientnet_model.py:143] round_filter input=320 output=320
# I0409 05:22:58.657354 140609851844416 efficientnet_model.py:143] round_filter input=1280 output=1280
# I0409 05:22:58.713407 140609851844416 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.0, resolution=224, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W0409 05:22:58.751087 140609851844416 deprecation.py:364] From /usr/local/lib/python3.9/dist-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['/content/Knifes-and-guns-4/train/knifes-guns.tfrecord']
# I0409 05:22:58.764735 140609851844416 dataset_builder.py:162] Reading unweighted datasets: ['/content/Knifes-and-guns-4/train/knifes-guns.tfrecord']
# INFO:tensorflow:Reading record datasets for input file: ['/content/Knifes-and-guns-4/train/knifes-guns.tfrecord']
# I0409 05:22:58.764922 140609851844416 dataset_builder.py:79] Reading record datasets for input file: ['/content/Knifes-and-guns-4/train/knifes-guns.tfrecord']
# INFO:tensorflow:Number of filenames to read: 1
# I0409 05:22:58.765008 140609851844416 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0409 05:22:58.765075 140609851844416 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0409 05:22:58.781489 140609851844416 deprecation.py:364] From /usr/local/lib/python3.9/dist-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0409 05:22:58.800797 140609851844416 deprecation.py:364] From /usr/local/lib/python3.9/dist-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0409 05:23:08.033752 140609851844416 deprecation.py:364] From /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0409 05:23:14.633110 140609851844416 deprecation.py:364] From /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/object_detection/builders/optimizer_builder.py:124: The name tf.keras.optimizers.SGD is deprecated. Please use tf.keras.optimizers.legacy.SGD instead.
#
# W0409 05:23:16.754480 140609851844416 module_wrapper.py:149] From /usr/local/lib/python3.9/dist-packages/object_detection/builders/optimizer_builder.py:124: The name tf.keras.optimizers.SGD is deprecated. Please use tf.keras.optimizers.legacy.SGD instead.
#
# /usr/local/lib/python3.9/dist-packages/keras/backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# I0409 05:23:25.232343 140604859012864 api.py:459] feature_map_spatial_dims: [(64, 64), (32, 32), (16, 16), (8, 8), (4, 4)]
# I0409 05:23:38.006365 140604859012864 api.py:459] feature_map_spatial_dims: [(64, 64), (32, 32), (16, 16), (8, 8), (4, 4)]
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/deprecation.py:648: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W0409 05:24:06.009768 140604965115648 deprecation.py:569] From /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/deprecation.py:648: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# I0409 05:24:08.168084 140604965115648 api.py:459] feature_map_spatial_dims: [(64, 64), (32, 32), (16, 16), (8, 8), (4, 4)]
# WARNING:tensorflow:Gradients do not exist for variables ['top_bn/gamma:0', 'top_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# W0409 05:24:17.281771 140604965115648 utils.py:82] Gradients do not exist for variables ['top_bn/gamma:0', 'top_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# I0409 05:24:24.415703 140604965115648 api.py:459] feature_map_spatial_dims: [(64, 64), (32, 32), (16, 16), (8, 8), (4, 4)]
# WARNING:tensorflow:Gradients do not exist for variables ['top_bn/gamma:0', 'top_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# W0409 05:24:33.027113 140604965115648 utils.py:82] Gradients do not exist for variables ['top_bn/gamma:0', 'top_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# I0409 05:24:38.272293 140604965115648 api.py:459] feature_map_spatial_dims: [(64, 64), (32, 32), (16, 16), (8, 8), (4, 4)]
# WARNING:tensorflow:Gradients do not exist for variables ['top_bn/gamma:0', 'top_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# W0409 05:24:47.667478 140604965115648 utils.py:82] Gradients do not exist for variables ['top_bn/gamma:0', 'top_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# I0409 05:24:51.929949 140604965115648 api.py:459] feature_map_spatial_dims: [(64, 64), (32, 32), (16, 16), (8, 8), (4, 4)]
# WARNING:tensorflow:Gradients do not exist for variables ['top_bn/gamma:0', 'top_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# W0409 05:25:03.167160 140604965115648 utils.py:82] Gradients do not exist for variables ['top_bn/gamma:0', 'top_bn/beta:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 2023-04-09 05:25:11.027209: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inEfficientDet-D0/model/stack_1/block_1/drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# INFO:tensorflow:Step 100 per-step time 2.036s
# I0409 05:27:29.394513 140609851844416 model_lib_v2.py:705] Step 100 per-step time 2.036s
# INFO:tensorflow:{'Loss/classification_loss': 1.1314511,
#  'Loss/localization_loss': 0.7104975,
#  'Loss/regularization_loss': 0.02834157,
#  'Loss/total_loss': 1.8702902,
#  'learning_rate': 0.00416}
# I0409 05:27:29.396936 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 1.1314511,
#  'Loss/localization_loss': 0.7104975,
#  'Loss/regularization_loss': 0.02834157,
#  'Loss/total_loss': 1.8702902,
#  'learning_rate': 0.00416}
# INFO:tensorflow:Step 200 per-step time 1.095s
# I0409 05:29:18.750414 140609851844416 model_lib_v2.py:705] Step 200 per-step time 1.095s
# INFO:tensorflow:{'Loss/classification_loss': 0.5347896,
#  'Loss/localization_loss': 0.5288611,
#  'Loss/regularization_loss': 0.028367577,
#  'Loss/total_loss': 1.0920184,
#  'learning_rate': 0.0073200003}
# I0409 05:29:18.751702 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.5347896,
#  'Loss/localization_loss': 0.5288611,
#  'Loss/regularization_loss': 0.028367577,
#  'Loss/total_loss': 1.0920184,
#  'learning_rate': 0.0073200003}
# INFO:tensorflow:Step 300 per-step time 1.092s
# I0409 05:31:07.957419 140609851844416 model_lib_v2.py:705] Step 300 per-step time 1.092s
# INFO:tensorflow:{'Loss/classification_loss': 0.4745151,
#  'Loss/localization_loss': 0.3571702,
#  'Loss/regularization_loss': 0.02843502,
#  'Loss/total_loss': 0.8601203,
#  'learning_rate': 0.010480001}
# I0409 05:31:07.957827 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.4745151,
#  'Loss/localization_loss': 0.3571702,
#  'Loss/regularization_loss': 0.02843502,
#  'Loss/total_loss': 0.8601203,
#  'learning_rate': 0.010480001}
# INFO:tensorflow:Step 400 per-step time 1.091s
# I0409 05:32:57.064197 140609851844416 model_lib_v2.py:705] Step 400 per-step time 1.091s
# INFO:tensorflow:{'Loss/classification_loss': 0.48374438,
#  'Loss/localization_loss': 0.358425,
#  'Loss/regularization_loss': 0.028541146,
#  'Loss/total_loss': 0.8707105,
#  'learning_rate': 0.0136400005}
# I0409 05:32:57.064543 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.48374438,
#  'Loss/localization_loss': 0.358425,
#  'Loss/regularization_loss': 0.028541146,
#  'Loss/total_loss': 0.8707105,
#  'learning_rate': 0.0136400005}
# INFO:tensorflow:Step 500 per-step time 1.089s
# I0409 05:34:45.963950 140609851844416 model_lib_v2.py:705] Step 500 per-step time 1.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.4747062,
#  'Loss/localization_loss': 0.3497052,
#  'Loss/regularization_loss': 0.02868878,
#  'Loss/total_loss': 0.8531002,
#  'learning_rate': 0.016800001}
# I0409 05:34:45.964361 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.4747062,
#  'Loss/localization_loss': 0.3497052,
#  'Loss/regularization_loss': 0.02868878,
#  'Loss/total_loss': 0.8531002,
#  'learning_rate': 0.016800001}
# INFO:tensorflow:Step 600 per-step time 1.089s
# I0409 05:36:34.825072 140609851844416 model_lib_v2.py:705] Step 600 per-step time 1.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.4927579,
#  'Loss/localization_loss': 0.3867059,
#  'Loss/regularization_loss': 0.028872488,
#  'Loss/total_loss': 0.9083363,
#  'learning_rate': 0.019960001}
# I0409 05:36:34.825496 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.4927579,
#  'Loss/localization_loss': 0.3867059,
#  'Loss/regularization_loss': 0.028872488,
#  'Loss/total_loss': 0.9083363,
#  'learning_rate': 0.019960001}
# INFO:tensorflow:Step 700 per-step time 1.089s
# I0409 05:38:23.706574 140609851844416 model_lib_v2.py:705] Step 700 per-step time 1.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.43129748,
#  'Loss/localization_loss': 0.24406928,
#  'Loss/regularization_loss': 0.029086728,
#  'Loss/total_loss': 0.70445347,
#  'learning_rate': 0.023120001}
# I0409 05:38:23.706988 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.43129748,
#  'Loss/localization_loss': 0.24406928,
#  'Loss/regularization_loss': 0.029086728,
#  'Loss/total_loss': 0.70445347,
#  'learning_rate': 0.023120001}
# INFO:tensorflow:Step 800 per-step time 1.092s
# I0409 05:40:12.881737 140609851844416 model_lib_v2.py:705] Step 800 per-step time 1.092s
# INFO:tensorflow:{'Loss/classification_loss': 0.50736743,
#  'Loss/localization_loss': 0.28391913,
#  'Loss/regularization_loss': 0.02932889,
#  'Loss/total_loss': 0.8206154,
#  'learning_rate': 0.02628}
# I0409 05:40:12.882079 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.50736743,
#  'Loss/localization_loss': 0.28391913,
#  'Loss/regularization_loss': 0.02932889,
#  'Loss/total_loss': 0.8206154,
#  'learning_rate': 0.02628}
# INFO:tensorflow:Step 900 per-step time 1.087s
# I0409 05:42:01.584311 140609851844416 model_lib_v2.py:705] Step 900 per-step time 1.087s
# INFO:tensorflow:{'Loss/classification_loss': 0.38498658,
#  'Loss/localization_loss': 0.25493994,
#  'Loss/regularization_loss': 0.029644374,
#  'Loss/total_loss': 0.6695709,
#  'learning_rate': 0.02944}
# I0409 05:42:01.584644 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.38498658,
#  'Loss/localization_loss': 0.25493994,
#  'Loss/regularization_loss': 0.029644374,
#  'Loss/total_loss': 0.6695709,
#  'learning_rate': 0.02944}
# INFO:tensorflow:Step 1000 per-step time 1.088s
# I0409 05:43:50.356125 140609851844416 model_lib_v2.py:705] Step 1000 per-step time 1.088s
# INFO:tensorflow:{'Loss/classification_loss': 0.46490452,
#  'Loss/localization_loss': 0.34214893,
#  'Loss/regularization_loss': 0.029990802,
#  'Loss/total_loss': 0.83704424,
#  'learning_rate': 0.0326}
# I0409 05:43:50.356478 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.46490452,
#  'Loss/localization_loss': 0.34214893,
#  'Loss/regularization_loss': 0.029990802,
#  'Loss/total_loss': 0.83704424,
#  'learning_rate': 0.0326}
# INFO:tensorflow:Step 1100 per-step time 1.108s
# I0409 05:45:41.206481 140609851844416 model_lib_v2.py:705] Step 1100 per-step time 1.108s
# INFO:tensorflow:{'Loss/classification_loss': 0.29565683,
#  'Loss/localization_loss': 0.18630543,
#  'Loss/regularization_loss': 0.030397523,
#  'Loss/total_loss': 0.5123598,
#  'learning_rate': 0.03576}
# I0409 05:45:41.206846 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.29565683,
#  'Loss/localization_loss': 0.18630543,
#  'Loss/regularization_loss': 0.030397523,
#  'Loss/total_loss': 0.5123598,
#  'learning_rate': 0.03576}
# INFO:tensorflow:Step 1200 per-step time 1.089s
# I0409 05:47:30.070852 140609851844416 model_lib_v2.py:705] Step 1200 per-step time 1.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.58952564,
#  'Loss/localization_loss': 0.33646658,
#  'Loss/regularization_loss': 0.030809933,
#  'Loss/total_loss': 0.9568021,
#  'learning_rate': 0.03892}
# I0409 05:47:30.071253 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.58952564,
#  'Loss/localization_loss': 0.33646658,
#  'Loss/regularization_loss': 0.030809933,
#  'Loss/total_loss': 0.9568021,
#  'learning_rate': 0.03892}
# INFO:tensorflow:Step 1300 per-step time 1.089s
# I0409 05:49:18.982797 140609851844416 model_lib_v2.py:705] Step 1300 per-step time 1.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.42694494,
#  'Loss/localization_loss': 0.33774886,
#  'Loss/regularization_loss': 0.031226384,
#  'Loss/total_loss': 0.7959202,
#  'learning_rate': 0.04208}
# I0409 05:49:18.983218 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.42694494,
#  'Loss/localization_loss': 0.33774886,
#  'Loss/regularization_loss': 0.031226384,
#  'Loss/total_loss': 0.7959202,
#  'learning_rate': 0.04208}
# INFO:tensorflow:Step 1400 per-step time 1.087s
# I0409 05:51:07.659476 140609851844416 model_lib_v2.py:705] Step 1400 per-step time 1.087s
# INFO:tensorflow:{'Loss/classification_loss': 0.3975434,
#  'Loss/localization_loss': 0.29594293,
#  'Loss/regularization_loss': 0.031697303,
#  'Loss/total_loss': 0.7251836,
#  'learning_rate': 0.04524}
# I0409 05:51:07.659852 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.3975434,
#  'Loss/localization_loss': 0.29594293,
#  'Loss/regularization_loss': 0.031697303,
#  'Loss/total_loss': 0.7251836,
#  'learning_rate': 0.04524}
# INFO:tensorflow:Step 1500 per-step time 1.088s
# I0409 05:52:56.416592 140609851844416 model_lib_v2.py:705] Step 1500 per-step time 1.088s
# INFO:tensorflow:{'Loss/classification_loss': 0.34776947,
#  'Loss/localization_loss': 0.24758829,
#  'Loss/regularization_loss': 0.032245614,
#  'Loss/total_loss': 0.62760335,
#  'learning_rate': 0.0484}
# I0409 05:52:56.416909 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.34776947,
#  'Loss/localization_loss': 0.24758829,
#  'Loss/regularization_loss': 0.032245614,
#  'Loss/total_loss': 0.62760335,
#  'learning_rate': 0.0484}
# INFO:tensorflow:Step 1600 per-step time 1.088s
# I0409 05:54:45.194419 140609851844416 model_lib_v2.py:705] Step 1600 per-step time 1.088s
# INFO:tensorflow:{'Loss/classification_loss': 0.383,
#  'Loss/localization_loss': 0.20608802,
#  'Loss/regularization_loss': 0.03275398,
#  'Loss/total_loss': 0.62184197,
#  'learning_rate': 0.05156}
# I0409 05:54:45.194734 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.383,
#  'Loss/localization_loss': 0.20608802,
#  'Loss/regularization_loss': 0.03275398,
#  'Loss/total_loss': 0.62184197,
#  'learning_rate': 0.05156}
# INFO:tensorflow:Step 1700 per-step time 1.087s
# I0409 05:56:33.941975 140609851844416 model_lib_v2.py:705] Step 1700 per-step time 1.087s
# INFO:tensorflow:{'Loss/classification_loss': 0.32277653,
#  'Loss/localization_loss': 0.22144926,
#  'Loss/regularization_loss': 0.03331478,
#  'Loss/total_loss': 0.5775406,
#  'learning_rate': 0.05472}
# I0409 05:56:33.942286 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.32277653,
#  'Loss/localization_loss': 0.22144926,
#  'Loss/regularization_loss': 0.03331478,
#  'Loss/total_loss': 0.5775406,
#  'learning_rate': 0.05472}
# INFO:tensorflow:Step 1800 per-step time 1.088s
# I0409 05:58:22.724145 140609851844416 model_lib_v2.py:705] Step 1800 per-step time 1.088s
# INFO:tensorflow:{'Loss/classification_loss': 0.43632185,
#  'Loss/localization_loss': 0.3126362,
#  'Loss/regularization_loss': 0.03389286,
#  'Loss/total_loss': 0.7828509,
#  'learning_rate': 0.05788}
# I0409 05:58:22.724548 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.43632185,
#  'Loss/localization_loss': 0.3126362,
#  'Loss/regularization_loss': 0.03389286,
#  'Loss/total_loss': 0.7828509,
#  'learning_rate': 0.05788}
# INFO:tensorflow:Step 1900 per-step time 1.088s
# I0409 06:00:11.487000 140609851844416 model_lib_v2.py:705] Step 1900 per-step time 1.088s
# INFO:tensorflow:{'Loss/classification_loss': 0.6734837,
#  'Loss/localization_loss': 0.44347253,
#  'Loss/regularization_loss': 0.03460599,
#  'Loss/total_loss': 1.1515622,
#  'learning_rate': 0.06104}
# I0409 06:00:11.487386 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.6734837,
#  'Loss/localization_loss': 0.44347253,
#  'Loss/regularization_loss': 0.03460599,
#  'Loss/total_loss': 1.1515622,
#  'learning_rate': 0.06104}
# INFO:tensorflow:Step 2000 per-step time 1.090s
# I0409 06:02:00.489937 140609851844416 model_lib_v2.py:705] Step 2000 per-step time 1.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.3736278,
#  'Loss/localization_loss': 0.21274267,
#  'Loss/regularization_loss': 0.035206992,
#  'Loss/total_loss': 0.6215775,
#  'learning_rate': 0.06420001}
# I0409 06:02:00.490356 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.3736278,
#  'Loss/localization_loss': 0.21274267,
#  'Loss/regularization_loss': 0.035206992,
#  'Loss/total_loss': 0.6215775,
#  'learning_rate': 0.06420001}
# INFO:tensorflow:Step 2100 per-step time 1.117s
# I0409 06:03:52.224311 140609851844416 model_lib_v2.py:705] Step 2100 per-step time 1.117s
# INFO:tensorflow:{'Loss/classification_loss': 0.30724403,
#  'Loss/localization_loss': 0.15121984,
#  'Loss/regularization_loss': 0.035841037,
#  'Loss/total_loss': 0.49430493,
#  'learning_rate': 0.067360006}
# I0409 06:03:52.224686 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.30724403,
#  'Loss/localization_loss': 0.15121984,
#  'Loss/regularization_loss': 0.035841037,
#  'Loss/total_loss': 0.49430493,
#  'learning_rate': 0.067360006}
# INFO:tensorflow:Step 2200 per-step time 1.084s
# I0409 06:05:40.569695 140609851844416 model_lib_v2.py:705] Step 2200 per-step time 1.084s
# INFO:tensorflow:{'Loss/classification_loss': 0.46898124,
#  'Loss/localization_loss': 0.36641508,
#  'Loss/regularization_loss': 0.03650296,
#  'Loss/total_loss': 0.8718993,
#  'learning_rate': 0.070520006}
# I0409 06:05:40.569999 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.46898124,
#  'Loss/localization_loss': 0.36641508,
#  'Loss/regularization_loss': 0.03650296,
#  'Loss/total_loss': 0.8718993,
#  'learning_rate': 0.070520006}
# INFO:tensorflow:Step 2300 per-step time 1.086s
# I0409 06:07:29.180027 140609851844416 model_lib_v2.py:705] Step 2300 per-step time 1.086s
# INFO:tensorflow:{'Loss/classification_loss': 0.31802058,
#  'Loss/localization_loss': 0.19674264,
#  'Loss/regularization_loss': 0.037245993,
#  'Loss/total_loss': 0.5520092,
#  'learning_rate': 0.073680006}
# I0409 06:07:29.180313 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.31802058,
#  'Loss/localization_loss': 0.19674264,
#  'Loss/regularization_loss': 0.037245993,
#  'Loss/total_loss': 0.5520092,
#  'learning_rate': 0.073680006}
# INFO:tensorflow:Step 2400 per-step time 1.087s
# I0409 06:09:17.920340 140609851844416 model_lib_v2.py:705] Step 2400 per-step time 1.087s
# INFO:tensorflow:{'Loss/classification_loss': 0.39002487,
#  'Loss/localization_loss': 0.26432306,
#  'Loss/regularization_loss': 0.038004745,
#  'Loss/total_loss': 0.69235265,
#  'learning_rate': 0.076840006}
# I0409 06:09:17.920633 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.39002487,
#  'Loss/localization_loss': 0.26432306,
#  'Loss/regularization_loss': 0.038004745,
#  'Loss/total_loss': 0.69235265,
#  'learning_rate': 0.076840006}
# INFO:tensorflow:Step 2500 per-step time 1.087s
# I0409 06:11:06.638569 140609851844416 model_lib_v2.py:705] Step 2500 per-step time 1.087s
# INFO:tensorflow:{'Loss/classification_loss': 0.2411482,
#  'Loss/localization_loss': 0.13499424,
#  'Loss/regularization_loss': 0.03866097,
#  'Loss/total_loss': 0.41480342,
#  'learning_rate': 0.08}
# I0409 06:11:06.638885 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.2411482,
#  'Loss/localization_loss': 0.13499424,
#  'Loss/regularization_loss': 0.03866097,
#  'Loss/total_loss': 0.41480342,
#  'learning_rate': 0.08}
# INFO:tensorflow:Step 2600 per-step time 1.087s
# I0409 06:12:55.342834 140609851844416 model_lib_v2.py:705] Step 2600 per-step time 1.087s
# INFO:tensorflow:{'Loss/classification_loss': 0.4062585,
#  'Loss/localization_loss': 0.32049248,
#  'Loss/regularization_loss': 0.039363444,
#  'Loss/total_loss': 0.7661144,
#  'learning_rate': 0.079999976}
# I0409 06:12:55.343226 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.4062585,
#  'Loss/localization_loss': 0.32049248,
#  'Loss/regularization_loss': 0.039363444,
#  'Loss/total_loss': 0.7661144,
#  'learning_rate': 0.079999976}
# INFO:tensorflow:Step 2700 per-step time 1.089s
# I0409 06:14:44.254107 140609851844416 model_lib_v2.py:705] Step 2700 per-step time 1.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.3555378,
#  'Loss/localization_loss': 0.23595645,
#  'Loss/regularization_loss': 0.040021833,
#  'Loss/total_loss': 0.6315161,
#  'learning_rate': 0.07999991}
# I0409 06:14:44.254461 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.3555378,
#  'Loss/localization_loss': 0.23595645,
#  'Loss/regularization_loss': 0.040021833,
#  'Loss/total_loss': 0.6315161,
#  'learning_rate': 0.07999991}
# INFO:tensorflow:Step 2800 per-step time 1.089s
# I0409 06:16:33.179247 140609851844416 model_lib_v2.py:705] Step 2800 per-step time 1.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.28660214,
#  'Loss/localization_loss': 0.20526727,
#  'Loss/regularization_loss': 0.04069195,
#  'Loss/total_loss': 0.53256136,
#  'learning_rate': 0.0799998}
# I0409 06:16:33.179579 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.28660214,
#  'Loss/localization_loss': 0.20526727,
#  'Loss/regularization_loss': 0.04069195,
#  'Loss/total_loss': 0.53256136,
#  'learning_rate': 0.0799998}
# INFO:tensorflow:Step 2900 per-step time 1.088s
# I0409 06:18:21.968816 140609851844416 model_lib_v2.py:705] Step 2900 per-step time 1.088s
# INFO:tensorflow:{'Loss/classification_loss': 0.40652362,
#  'Loss/localization_loss': 0.22831081,
#  'Loss/regularization_loss': 0.041295614,
#  'Loss/total_loss': 0.67613006,
#  'learning_rate': 0.07999964}
# I0409 06:18:21.969107 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.40652362,
#  'Loss/localization_loss': 0.22831081,
#  'Loss/regularization_loss': 0.041295614,
#  'Loss/total_loss': 0.67613006,
#  'learning_rate': 0.07999964}
# INFO:tensorflow:Step 3000 per-step time 1.091s
# I0409 06:20:11.105581 140609851844416 model_lib_v2.py:705] Step 3000 per-step time 1.091s
# INFO:tensorflow:{'Loss/classification_loss': 0.42062166,
#  'Loss/localization_loss': 0.26556912,
#  'Loss/regularization_loss': 0.04190363,
#  'Loss/total_loss': 0.72809446,
#  'learning_rate': 0.07999944}
# I0409 06:20:11.105871 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.42062166,
#  'Loss/localization_loss': 0.26556912,
#  'Loss/regularization_loss': 0.04190363,
#  'Loss/total_loss': 0.72809446,
#  'learning_rate': 0.07999944}
# INFO:tensorflow:Step 3100 per-step time 1.111s
# I0409 06:22:02.166330 140609851844416 model_lib_v2.py:705] Step 3100 per-step time 1.111s
# INFO:tensorflow:{'Loss/classification_loss': 0.47574994,
#  'Loss/localization_loss': 0.36527207,
#  'Loss/regularization_loss': 0.0425299,
#  'Loss/total_loss': 0.88355196,
#  'learning_rate': 0.07999919}
# I0409 06:22:02.166659 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.47574994,
#  'Loss/localization_loss': 0.36527207,
#  'Loss/regularization_loss': 0.0425299,
#  'Loss/total_loss': 0.88355196,
#  'learning_rate': 0.07999919}
# INFO:tensorflow:Step 3200 per-step time 1.087s
# I0409 06:23:50.892745 140609851844416 model_lib_v2.py:705] Step 3200 per-step time 1.087s
# INFO:tensorflow:{'Loss/classification_loss': 0.39988354,
#  'Loss/localization_loss': 0.315007,
#  'Loss/regularization_loss': 0.04313766,
#  'Loss/total_loss': 0.7580282,
#  'learning_rate': 0.0799989}
# I0409 06:23:50.893058 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.39988354,
#  'Loss/localization_loss': 0.315007,
#  'Loss/regularization_loss': 0.04313766,
#  'Loss/total_loss': 0.7580282,
#  'learning_rate': 0.0799989}
# INFO:tensorflow:Step 3300 per-step time 1.087s
# I0409 06:25:39.556666 140609851844416 model_lib_v2.py:705] Step 3300 per-step time 1.087s
# INFO:tensorflow:{'Loss/classification_loss': 0.4017505,
#  'Loss/localization_loss': 0.33034503,
#  'Loss/regularization_loss': 0.04367203,
#  'Loss/total_loss': 0.77576756,
#  'learning_rate': 0.07999857}
# I0409 06:25:39.556954 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.4017505,
#  'Loss/localization_loss': 0.33034503,
#  'Loss/regularization_loss': 0.04367203,
#  'Loss/total_loss': 0.77576756,
#  'learning_rate': 0.07999857}
# INFO:tensorflow:Step 3400 per-step time 1.085s
# I0409 06:27:28.091662 140609851844416 model_lib_v2.py:705] Step 3400 per-step time 1.085s
# INFO:tensorflow:{'Loss/classification_loss': 0.3020421,
#  'Loss/localization_loss': 0.2159437,
#  'Loss/regularization_loss': 0.04421898,
#  'Loss/total_loss': 0.5622048,
#  'learning_rate': 0.07999819}
# I0409 06:27:28.092059 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.3020421,
#  'Loss/localization_loss': 0.2159437,
#  'Loss/regularization_loss': 0.04421898,
#  'Loss/total_loss': 0.5622048,
#  'learning_rate': 0.07999819}
# INFO:tensorflow:Step 3500 per-step time 1.087s
# I0409 06:29:16.781236 140609851844416 model_lib_v2.py:705] Step 3500 per-step time 1.087s
# INFO:tensorflow:{'Loss/classification_loss': 0.333338,
#  'Loss/localization_loss': 0.18754365,
#  'Loss/regularization_loss': 0.04467392,
#  'Loss/total_loss': 0.5655556,
#  'learning_rate': 0.07999776}
# I0409 06:29:16.781583 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.333338,
#  'Loss/localization_loss': 0.18754365,
#  'Loss/regularization_loss': 0.04467392,
#  'Loss/total_loss': 0.5655556,
#  'learning_rate': 0.07999776}
# INFO:tensorflow:Step 3600 per-step time 1.087s
# I0409 06:31:05.472824 140609851844416 model_lib_v2.py:705] Step 3600 per-step time 1.087s
# INFO:tensorflow:{'Loss/classification_loss': 0.374607,
#  'Loss/localization_loss': 0.25744537,
#  'Loss/regularization_loss': 0.045181014,
#  'Loss/total_loss': 0.67723334,
#  'learning_rate': 0.0799973}
# I0409 06:31:05.473101 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.374607,
#  'Loss/localization_loss': 0.25744537,
#  'Loss/regularization_loss': 0.045181014,
#  'Loss/total_loss': 0.67723334,
#  'learning_rate': 0.0799973}
# INFO:tensorflow:Step 3700 per-step time 1.087s
# I0409 06:32:54.130178 140609851844416 model_lib_v2.py:705] Step 3700 per-step time 1.087s
# INFO:tensorflow:{'Loss/classification_loss': 0.30166635,
#  'Loss/localization_loss': 0.20394094,
#  'Loss/regularization_loss': 0.045668505,
#  'Loss/total_loss': 0.5512758,
#  'learning_rate': 0.07999679}
# I0409 06:32:54.130464 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.30166635,
#  'Loss/localization_loss': 0.20394094,
#  'Loss/regularization_loss': 0.045668505,
#  'Loss/total_loss': 0.5512758,
#  'learning_rate': 0.07999679}
# INFO:tensorflow:Step 3800 per-step time 1.087s
# I0409 06:34:42.864129 140609851844416 model_lib_v2.py:705] Step 3800 per-step time 1.087s
# INFO:tensorflow:{'Loss/classification_loss': 0.34763172,
#  'Loss/localization_loss': 0.14495566,
#  'Loss/regularization_loss': 0.046158746,
#  'Loss/total_loss': 0.5387461,
#  'learning_rate': 0.07999623}
# I0409 06:34:42.864404 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.34763172,
#  'Loss/localization_loss': 0.14495566,
#  'Loss/regularization_loss': 0.046158746,
#  'Loss/total_loss': 0.5387461,
#  'learning_rate': 0.07999623}
# INFO:tensorflow:Step 3900 per-step time 1.089s
# I0409 06:36:31.768613 140609851844416 model_lib_v2.py:705] Step 3900 per-step time 1.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.30520162,
#  'Loss/localization_loss': 0.26589027,
#  'Loss/regularization_loss': 0.04658411,
#  'Loss/total_loss': 0.617676,
#  'learning_rate': 0.07999563}
# I0409 06:36:31.768928 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.30520162,
#  'Loss/localization_loss': 0.26589027,
#  'Loss/regularization_loss': 0.04658411,
#  'Loss/total_loss': 0.617676,
#  'learning_rate': 0.07999563}
# INFO:tensorflow:Step 4000 per-step time 1.088s
# I0409 06:38:20.579477 140609851844416 model_lib_v2.py:705] Step 4000 per-step time 1.088s
# INFO:tensorflow:{'Loss/classification_loss': 0.31404904,
#  'Loss/localization_loss': 0.21549073,
#  'Loss/regularization_loss': 0.047011398,
#  'Loss/total_loss': 0.5765512,
#  'learning_rate': 0.079994984}
# I0409 06:38:20.579789 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.31404904,
#  'Loss/localization_loss': 0.21549073,
#  'Loss/regularization_loss': 0.047011398,
#  'Loss/total_loss': 0.5765512,
#  'learning_rate': 0.079994984}
# INFO:tensorflow:Step 4100 per-step time 1.108s
# I0409 06:40:11.334870 140609851844416 model_lib_v2.py:705] Step 4100 per-step time 1.108s
# INFO:tensorflow:{'Loss/classification_loss': 0.32771295,
#  'Loss/localization_loss': 0.23515265,
#  'Loss/regularization_loss': 0.047417484,
#  'Loss/total_loss': 0.6102831,
#  'learning_rate': 0.07999428}
# I0409 06:40:11.335223 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.32771295,
#  'Loss/localization_loss': 0.23515265,
#  'Loss/regularization_loss': 0.047417484,
#  'Loss/total_loss': 0.6102831,
#  'learning_rate': 0.07999428}
# INFO:tensorflow:Step 4200 per-step time 1.088s
# I0409 06:42:00.103890 140609851844416 model_lib_v2.py:705] Step 4200 per-step time 1.088s
# INFO:tensorflow:{'Loss/classification_loss': 0.3490192,
#  'Loss/localization_loss': 0.24317797,
#  'Loss/regularization_loss': 0.047869448,
#  'Loss/total_loss': 0.6400666,
#  'learning_rate': 0.07999355}
# I0409 06:42:00.104236 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.3490192,
#  'Loss/localization_loss': 0.24317797,
#  'Loss/regularization_loss': 0.047869448,
#  'Loss/total_loss': 0.6400666,
#  'learning_rate': 0.07999355}
# INFO:tensorflow:Step 4300 per-step time 1.088s
# I0409 06:43:48.896745 140609851844416 model_lib_v2.py:705] Step 4300 per-step time 1.088s
# INFO:tensorflow:{'Loss/classification_loss': 0.35272264,
#  'Loss/localization_loss': 0.263548,
#  'Loss/regularization_loss': 0.048268855,
#  'Loss/total_loss': 0.66453946,
#  'learning_rate': 0.07999277}
# I0409 06:43:48.897349 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.35272264,
#  'Loss/localization_loss': 0.263548,
#  'Loss/regularization_loss': 0.048268855,
#  'Loss/total_loss': 0.66453946,
#  'learning_rate': 0.07999277}
# INFO:tensorflow:Step 4400 per-step time 1.089s
# I0409 06:45:37.785901 140609851844416 model_lib_v2.py:705] Step 4400 per-step time 1.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.27597567,
#  'Loss/localization_loss': 0.19041774,
#  'Loss/regularization_loss': 0.04866059,
#  'Loss/total_loss': 0.515054,
#  'learning_rate': 0.07999195}
# I0409 06:45:37.786197 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.27597567,
#  'Loss/localization_loss': 0.19041774,
#  'Loss/regularization_loss': 0.04866059,
#  'Loss/total_loss': 0.515054,
#  'learning_rate': 0.07999195}
# INFO:tensorflow:Step 4500 per-step time 1.091s
# I0409 06:47:26.872245 140609851844416 model_lib_v2.py:705] Step 4500 per-step time 1.091s
# INFO:tensorflow:{'Loss/classification_loss': 0.32182068,
#  'Loss/localization_loss': 0.19995327,
#  'Loss/regularization_loss': 0.049059436,
#  'Loss/total_loss': 0.5708334,
#  'learning_rate': 0.07999108}
# I0409 06:47:26.872532 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.32182068,
#  'Loss/localization_loss': 0.19995327,
#  'Loss/regularization_loss': 0.049059436,
#  'Loss/total_loss': 0.5708334,
#  'learning_rate': 0.07999108}
# INFO:tensorflow:Step 4600 per-step time 1.090s
# I0409 06:49:15.896485 140609851844416 model_lib_v2.py:705] Step 4600 per-step time 1.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.25806153,
#  'Loss/localization_loss': 0.12089262,
#  'Loss/regularization_loss': 0.04941409,
#  'Loss/total_loss': 0.42836824,
#  'learning_rate': 0.07999016}
# I0409 06:49:15.896844 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.25806153,
#  'Loss/localization_loss': 0.12089262,
#  'Loss/regularization_loss': 0.04941409,
#  'Loss/total_loss': 0.42836824,
#  'learning_rate': 0.07999016}
# INFO:tensorflow:Step 4700 per-step time 1.087s
# I0409 06:51:04.622811 140609851844416 model_lib_v2.py:705] Step 4700 per-step time 1.087s
# INFO:tensorflow:{'Loss/classification_loss': 0.26295516,
#  'Loss/localization_loss': 0.17076999,
#  'Loss/regularization_loss': 0.04980198,
#  'Loss/total_loss': 0.48352712,
#  'learning_rate': 0.0799892}
# I0409 06:51:04.623177 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.26295516,
#  'Loss/localization_loss': 0.17076999,
#  'Loss/regularization_loss': 0.04980198,
#  'Loss/total_loss': 0.48352712,
#  'learning_rate': 0.0799892}
# INFO:tensorflow:Step 4800 per-step time 1.090s
# I0409 06:52:53.641855 140609851844416 model_lib_v2.py:705] Step 4800 per-step time 1.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.34946945,
#  'Loss/localization_loss': 0.24202189,
#  'Loss/regularization_loss': 0.050197877,
#  'Loss/total_loss': 0.6416892,
#  'learning_rate': 0.079988204}
# I0409 06:52:53.642137 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.34946945,
#  'Loss/localization_loss': 0.24202189,
#  'Loss/regularization_loss': 0.050197877,
#  'Loss/total_loss': 0.6416892,
#  'learning_rate': 0.079988204}
# INFO:tensorflow:Step 4900 per-step time 1.087s
# I0409 06:54:42.317801 140609851844416 model_lib_v2.py:705] Step 4900 per-step time 1.087s
# INFO:tensorflow:{'Loss/classification_loss': 0.33690175,
#  'Loss/localization_loss': 0.28125322,
#  'Loss/regularization_loss': 0.05058168,
#  'Loss/total_loss': 0.66873664,
#  'learning_rate': 0.07998715}
# I0409 06:54:42.318149 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.33690175,
#  'Loss/localization_loss': 0.28125322,
#  'Loss/regularization_loss': 0.05058168,
#  'Loss/total_loss': 0.66873664,
#  'learning_rate': 0.07998715}
# INFO:tensorflow:Step 5000 per-step time 1.092s
# I0409 06:56:31.533909 140609851844416 model_lib_v2.py:705] Step 5000 per-step time 1.092s
# INFO:tensorflow:{'Loss/classification_loss': 0.22996385,
#  'Loss/localization_loss': 0.10367203,
#  'Loss/regularization_loss': 0.05093861,
#  'Loss/total_loss': 0.3845745,
#  'learning_rate': 0.07998606}
# I0409 06:56:31.534192 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.22996385,
#  'Loss/localization_loss': 0.10367203,
#  'Loss/regularization_loss': 0.05093861,
#  'Loss/total_loss': 0.3845745,
#  'learning_rate': 0.07998606}
# INFO:tensorflow:Step 5100 per-step time 1.115s
# I0409 06:58:23.009289 140609851844416 model_lib_v2.py:705] Step 5100 per-step time 1.115s
# INFO:tensorflow:{'Loss/classification_loss': 0.31449184,
#  'Loss/localization_loss': 0.20122963,
#  'Loss/regularization_loss': 0.051269062,
#  'Loss/total_loss': 0.5669905,
#  'learning_rate': 0.07998492}
# I0409 06:58:23.009588 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.31449184,
#  'Loss/localization_loss': 0.20122963,
#  'Loss/regularization_loss': 0.051269062,
#  'Loss/total_loss': 0.5669905,
#  'learning_rate': 0.07998492}
# INFO:tensorflow:Step 5200 per-step time 1.087s
# I0409 07:00:11.663696 140609851844416 model_lib_v2.py:705] Step 5200 per-step time 1.087s
# INFO:tensorflow:{'Loss/classification_loss': 0.36428094,
#  'Loss/localization_loss': 0.23069961,
#  'Loss/regularization_loss': 0.05160432,
#  'Loss/total_loss': 0.64658487,
#  'learning_rate': 0.07998374}
# I0409 07:00:11.664047 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.36428094,
#  'Loss/localization_loss': 0.23069961,
#  'Loss/regularization_loss': 0.05160432,
#  'Loss/total_loss': 0.64658487,
#  'learning_rate': 0.07998374}
# INFO:tensorflow:Step 5300 per-step time 1.087s
# I0409 07:02:00.319555 140609851844416 model_lib_v2.py:705] Step 5300 per-step time 1.087s
# INFO:tensorflow:{'Loss/classification_loss': 0.22041692,
#  'Loss/localization_loss': 0.11639463,
#  'Loss/regularization_loss': 0.051915444,
#  'Loss/total_loss': 0.388727,
#  'learning_rate': 0.07998252}
# I0409 07:02:00.319852 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.22041692,
#  'Loss/localization_loss': 0.11639463,
#  'Loss/regularization_loss': 0.051915444,
#  'Loss/total_loss': 0.388727,
#  'learning_rate': 0.07998252}
# INFO:tensorflow:Step 5400 per-step time 1.086s
# I0409 07:03:48.941483 140609851844416 model_lib_v2.py:705] Step 5400 per-step time 1.086s
# INFO:tensorflow:{'Loss/classification_loss': 0.32348698,
#  'Loss/localization_loss': 0.17264256,
#  'Loss/regularization_loss': 0.052325968,
#  'Loss/total_loss': 0.5484555,
#  'learning_rate': 0.079981245}
# I0409 07:03:48.941760 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.32348698,
#  'Loss/localization_loss': 0.17264256,
#  'Loss/regularization_loss': 0.052325968,
#  'Loss/total_loss': 0.5484555,
# ...
#  'Loss/localization_loss': 0.22697455,
#  'Loss/regularization_loss': 0.053278655,
#  'Loss/total_loss': 0.5336441,
#  'learning_rate': 0.07997716}
# I0409 07:09:15.515917 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.25339085,
#  'Loss/localization_loss': 0.22697455,
#  'Loss/regularization_loss': 0.053278655,
#  'Loss/total_loss': 0.5336441,
#  'learning_rate': 0.07997716}
# INFO:tensorflow:Step 5800 per-step time 1.090s
# I0409 07:11:04.540420 140609851844416 model_lib_v2.py:705] Step 5800 per-step time 1.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.20414355,
#  'Loss/localization_loss': 0.10616949,
#  'Loss/regularization_loss': 0.053637207,
#  'Loss/total_loss': 0.36395025,
#  'learning_rate': 0.07997571}
# I0409 07:11:04.540742 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.20414355,
#  'Loss/localization_loss': 0.10616949,
#  'Loss/regularization_loss': 0.053637207,
#  'Loss/total_loss': 0.36395025,
#  'learning_rate': 0.07997571}
# INFO:tensorflow:Step 5900 per-step time 1.091s
# I0409 07:12:53.688545 140609851844416 model_lib_v2.py:705] Step 5900 per-step time 1.091s
# INFO:tensorflow:{'Loss/classification_loss': 0.2898575,
#  'Loss/localization_loss': 0.1876609,
#  'Loss/regularization_loss': 0.053939737,
#  'Loss/total_loss': 0.53145814,
#  'learning_rate': 0.07997422}
# I0409 07:12:53.688861 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.2898575,
#  'Loss/localization_loss': 0.1876609,
#  'Loss/regularization_loss': 0.053939737,
#  'Loss/total_loss': 0.53145814,
#  'learning_rate': 0.07997422}
# INFO:tensorflow:Step 6000 per-step time 1.090s
# I0409 07:14:42.710987 140609851844416 model_lib_v2.py:705] Step 6000 per-step time 1.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.27374223,
#  'Loss/localization_loss': 0.15407674,
#  'Loss/regularization_loss': 0.054233972,
#  'Loss/total_loss': 0.48205292,
#  'learning_rate': 0.07997268}
# I0409 07:14:42.711344 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.27374223,
#  'Loss/localization_loss': 0.15407674,
#  'Loss/regularization_loss': 0.054233972,
#  'Loss/total_loss': 0.48205292,
#  'learning_rate': 0.07997268}
# INFO:tensorflow:Step 6100 per-step time 1.123s
# I0409 07:16:34.964760 140609851844416 model_lib_v2.py:705] Step 6100 per-step time 1.123s
# INFO:tensorflow:{'Loss/classification_loss': 0.34776175,
#  'Loss/localization_loss': 0.19654122,
#  'Loss/regularization_loss': 0.054525834,
#  'Loss/total_loss': 0.5988288,
#  'learning_rate': 0.0799711}
# I0409 07:16:34.965412 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.34776175,
#  'Loss/localization_loss': 0.19654122,
#  'Loss/regularization_loss': 0.054525834,
#  'Loss/total_loss': 0.5988288,
#  'learning_rate': 0.0799711}
# INFO:tensorflow:Step 6200 per-step time 1.087s
# I0409 07:18:23.667868 140609851844416 model_lib_v2.py:705] Step 6200 per-step time 1.087s
# INFO:tensorflow:{'Loss/classification_loss': 0.26264107,
#  'Loss/localization_loss': 0.19168377,
#  'Loss/regularization_loss': 0.05482121,
#  'Loss/total_loss': 0.5091461,
#  'learning_rate': 0.07996947}
# I0409 07:18:23.668215 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.26264107,
#  'Loss/localization_loss': 0.19168377,
#  'Loss/regularization_loss': 0.05482121,
#  'Loss/total_loss': 0.5091461,
#  'learning_rate': 0.07996947}
# INFO:tensorflow:Step 6300 per-step time 1.086s
# I0409 07:20:12.313365 140609851844416 model_lib_v2.py:705] Step 6300 per-step time 1.086s
# INFO:tensorflow:{'Loss/classification_loss': 0.2522468,
#  'Loss/localization_loss': 0.19137074,
#  'Loss/regularization_loss': 0.05507746,
#  'Loss/total_loss': 0.49869502,
#  'learning_rate': 0.0799678}
# I0409 07:20:12.313687 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.2522468,
#  'Loss/localization_loss': 0.19137074,
#  'Loss/regularization_loss': 0.05507746,
#  'Loss/total_loss': 0.49869502,
#  'learning_rate': 0.0799678}
# INFO:tensorflow:Step 6400 per-step time 1.086s
# I0409 07:22:00.924953 140609851844416 model_lib_v2.py:705] Step 6400 per-step time 1.086s
# INFO:tensorflow:{'Loss/classification_loss': 0.2854947,
#  'Loss/localization_loss': 0.21272153,
#  'Loss/regularization_loss': 0.05538252,
#  'Loss/total_loss': 0.55359876,
#  'learning_rate': 0.07996608}
# I0409 07:22:00.925471 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.2854947,
#  'Loss/localization_loss': 0.21272153,
#  'Loss/regularization_loss': 0.05538252,
#  'Loss/total_loss': 0.55359876,
#  'learning_rate': 0.07996608}
# INFO:tensorflow:Step 6500 per-step time 1.084s
# I0409 07:23:49.366419 140609851844416 model_lib_v2.py:705] Step 6500 per-step time 1.084s
# INFO:tensorflow:{'Loss/classification_loss': 0.32740152,
#  'Loss/localization_loss': 0.2520069,
#  'Loss/regularization_loss': 0.05567693,
#  'Loss/total_loss': 0.63508534,
#  'learning_rate': 0.079964325}
# I0409 07:23:49.366701 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.32740152,
#  'Loss/localization_loss': 0.2520069,
#  'Loss/regularization_loss': 0.05567693,
#  'Loss/total_loss': 0.63508534,
#  'learning_rate': 0.079964325}
# INFO:tensorflow:Step 6600 per-step time 1.086s
# I0409 07:25:37.940150 140609851844416 model_lib_v2.py:705] Step 6600 per-step time 1.086s
# INFO:tensorflow:{'Loss/classification_loss': 0.37231293,
#  'Loss/localization_loss': 0.21365611,
#  'Loss/regularization_loss': 0.055918045,
#  'Loss/total_loss': 0.64188707,
#  'learning_rate': 0.079962514}
# I0409 07:25:37.940436 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.37231293,
#  'Loss/localization_loss': 0.21365611,
#  'Loss/regularization_loss': 0.055918045,
#  'Loss/total_loss': 0.64188707,
#  'learning_rate': 0.079962514}
# INFO:tensorflow:Step 6700 per-step time 1.088s
# I0409 07:27:26.783340 140609851844416 model_lib_v2.py:705] Step 6700 per-step time 1.088s
# INFO:tensorflow:{'Loss/classification_loss': 0.27792054,
#  'Loss/localization_loss': 0.2254194,
#  'Loss/regularization_loss': 0.056171782,
#  'Loss/total_loss': 0.5595117,
#  'learning_rate': 0.07996067}
# I0409 07:27:26.783631 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.27792054,
#  'Loss/localization_loss': 0.2254194,
#  'Loss/regularization_loss': 0.056171782,
#  'Loss/total_loss': 0.5595117,
#  'learning_rate': 0.07996067}
# INFO:tensorflow:Step 6800 per-step time 1.090s
# I0409 07:29:15.764206 140609851844416 model_lib_v2.py:705] Step 6800 per-step time 1.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.4139134,
#  'Loss/localization_loss': 0.3048918,
#  'Loss/regularization_loss': 0.05644525,
#  'Loss/total_loss': 0.77525043,
#  'learning_rate': 0.079958774}
# I0409 07:29:15.764595 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.4139134,
#  'Loss/localization_loss': 0.3048918,
#  'Loss/regularization_loss': 0.05644525,
#  'Loss/total_loss': 0.77525043,
#  'learning_rate': 0.079958774}
# INFO:tensorflow:Step 6900 per-step time 1.090s
# I0409 07:31:04.716807 140609851844416 model_lib_v2.py:705] Step 6900 per-step time 1.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.23253343,
#  'Loss/localization_loss': 0.17378284,
#  'Loss/regularization_loss': 0.056683995,
#  'Loss/total_loss': 0.46300024,
#  'learning_rate': 0.07995682}
# I0409 07:31:04.717161 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.23253343,
#  'Loss/localization_loss': 0.17378284,
#  'Loss/regularization_loss': 0.056683995,
#  'Loss/total_loss': 0.46300024,
#  'learning_rate': 0.07995682}
# INFO:tensorflow:Step 7000 per-step time 1.088s
# I0409 07:32:53.534071 140609851844416 model_lib_v2.py:705] Step 7000 per-step time 1.088s
# INFO:tensorflow:{'Loss/classification_loss': 0.2938637,
#  'Loss/localization_loss': 0.18647021,
#  'Loss/regularization_loss': 0.056945074,
#  'Loss/total_loss': 0.537279,
#  'learning_rate': 0.07995484}
# I0409 07:32:53.534427 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.2938637,
#  'Loss/localization_loss': 0.18647021,
#  'Loss/regularization_loss': 0.056945074,
#  'Loss/total_loss': 0.537279,
#  'learning_rate': 0.07995484}
# INFO:tensorflow:Step 7100 per-step time 1.121s
# I0409 07:34:45.615870 140609851844416 model_lib_v2.py:705] Step 7100 per-step time 1.121s
# INFO:tensorflow:{'Loss/classification_loss': 0.2464981,
#  'Loss/localization_loss': 0.13496071,
#  'Loss/regularization_loss': 0.057199385,
#  'Loss/total_loss': 0.43865818,
#  'learning_rate': 0.07995281}
# I0409 07:34:45.616223 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.2464981,
#  'Loss/localization_loss': 0.13496071,
#  'Loss/regularization_loss': 0.057199385,
#  'Loss/total_loss': 0.43865818,
#  'learning_rate': 0.07995281}
# INFO:tensorflow:Step 7200 per-step time 1.090s
# I0409 07:36:34.639579 140609851844416 model_lib_v2.py:705] Step 7200 per-step time 1.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.3316826,
#  'Loss/localization_loss': 0.20227683,
#  'Loss/regularization_loss': 0.05747156,
#  'Loss/total_loss': 0.59143096,
#  'learning_rate': 0.07995074}
# I0409 07:36:34.639878 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.3316826,
#  'Loss/localization_loss': 0.20227683,
#  'Loss/regularization_loss': 0.05747156,
#  'Loss/total_loss': 0.59143096,
#  'learning_rate': 0.07995074}
# INFO:tensorflow:Step 7300 per-step time 1.089s
# I0409 07:38:23.540497 140609851844416 model_lib_v2.py:705] Step 7300 per-step time 1.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.22197121,
#  'Loss/localization_loss': 0.11523165,
#  'Loss/regularization_loss': 0.057741385,
#  'Loss/total_loss': 0.39494425,
#  'learning_rate': 0.07994863}
# I0409 07:38:23.540802 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.22197121,
#  'Loss/localization_loss': 0.11523165,
#  'Loss/regularization_loss': 0.057741385,
#  'Loss/total_loss': 0.39494425,
#  'learning_rate': 0.07994863}
# INFO:tensorflow:Step 7400 per-step time 1.088s
# I0409 07:40:12.332740 140609851844416 model_lib_v2.py:705] Step 7400 per-step time 1.088s
# INFO:tensorflow:{'Loss/classification_loss': 0.338045,
#  'Loss/localization_loss': 0.21778095,
#  'Loss/regularization_loss': 0.0580088,
#  'Loss/total_loss': 0.61383474,
#  'learning_rate': 0.07994646}
# I0409 07:40:12.333037 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.338045,
#  'Loss/localization_loss': 0.21778095,
#  'Loss/regularization_loss': 0.0580088,
#  'Loss/total_loss': 0.61383474,
#  'learning_rate': 0.07994646}
# INFO:tensorflow:Step 7500 per-step time 1.087s
# I0409 07:42:01.081434 140609851844416 model_lib_v2.py:705] Step 7500 per-step time 1.087s
# INFO:tensorflow:{'Loss/classification_loss': 0.20759062,
#  'Loss/localization_loss': 0.13162492,
#  'Loss/regularization_loss': 0.058276683,
#  'Loss/total_loss': 0.39749223,
#  'learning_rate': 0.07994425}
# I0409 07:42:01.081724 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.20759062,
#  'Loss/localization_loss': 0.13162492,
#  'Loss/regularization_loss': 0.058276683,
#  'Loss/total_loss': 0.39749223,
#  'learning_rate': 0.07994425}
# INFO:tensorflow:Step 7600 per-step time 1.087s
# I0409 07:43:49.752384 140609851844416 model_lib_v2.py:705] Step 7600 per-step time 1.087s
# INFO:tensorflow:{'Loss/classification_loss': 0.22327217,
#  'Loss/localization_loss': 0.10838211,
#  'Loss/regularization_loss': 0.058573224,
#  'Loss/total_loss': 0.3902275,
#  'learning_rate': 0.079942}
# I0409 07:43:49.752743 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.22327217,
#  'Loss/localization_loss': 0.10838211,
#  'Loss/regularization_loss': 0.058573224,
#  'Loss/total_loss': 0.3902275,
#  'learning_rate': 0.079942}
# INFO:tensorflow:Step 7700 per-step time 1.090s
# I0409 07:45:38.729557 140609851844416 model_lib_v2.py:705] Step 7700 per-step time 1.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.3173438,
#  'Loss/localization_loss': 0.19241785,
#  'Loss/regularization_loss': 0.058860883,
#  'Loss/total_loss': 0.5686225,
#  'learning_rate': 0.07993971}
# I0409 07:45:38.729954 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.3173438,
#  'Loss/localization_loss': 0.19241785,
#  'Loss/regularization_loss': 0.058860883,
#  'Loss/total_loss': 0.5686225,
#  'learning_rate': 0.07993971}
# INFO:tensorflow:Step 7800 per-step time 1.087s
# I0409 07:47:27.447717 140609851844416 model_lib_v2.py:705] Step 7800 per-step time 1.087s
# INFO:tensorflow:{'Loss/classification_loss': 0.32004923,
#  'Loss/localization_loss': 0.230207,
#  'Loss/regularization_loss': 0.059152216,
#  'Loss/total_loss': 0.60940844,
#  'learning_rate': 0.07993737}
# I0409 07:47:27.448064 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.32004923,
#  'Loss/localization_loss': 0.230207,
#  'Loss/regularization_loss': 0.059152216,
#  'Loss/total_loss': 0.60940844,
#  'learning_rate': 0.07993737}
# INFO:tensorflow:Step 7900 per-step time 1.090s
# I0409 07:49:16.418116 140609851844416 model_lib_v2.py:705] Step 7900 per-step time 1.090s
# INFO:tensorflow:{'Loss/classification_loss': 0.326371,
#  'Loss/localization_loss': 0.17796297,
#  'Loss/regularization_loss': 0.059465855,
#  'Loss/total_loss': 0.56379986,
#  'learning_rate': 0.079934984}
# I0409 07:49:16.418394 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.326371,
#  'Loss/localization_loss': 0.17796297,
#  'Loss/regularization_loss': 0.059465855,
#  'Loss/total_loss': 0.56379986,
#  'learning_rate': 0.079934984}
# INFO:tensorflow:Step 8000 per-step time 1.089s
# I0409 07:51:05.329479 140609851844416 model_lib_v2.py:705] Step 8000 per-step time 1.089s
# INFO:tensorflow:{'Loss/classification_loss': 0.23038459,
#  'Loss/localization_loss': 0.15339181,
#  'Loss/regularization_loss': 0.059711702,
#  'Loss/total_loss': 0.4434881,
#  'learning_rate': 0.079932556}
# I0409 07:51:05.329823 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.23038459,
#  'Loss/localization_loss': 0.15339181,
#  'Loss/regularization_loss': 0.059711702,
#  'Loss/total_loss': 0.4434881,
#  'learning_rate': 0.079932556}
# INFO:tensorflow:Step 8100 per-step time 1.107s
# I0409 07:52:56.051875 140609851844416 model_lib_v2.py:705] Step 8100 per-step time 1.107s
# INFO:tensorflow:{'Loss/classification_loss': 0.22821812,
#  'Loss/localization_loss': 0.14769623,
#  'Loss/regularization_loss': 0.05996919,
#  'Loss/total_loss': 0.43588355,
#  'learning_rate': 0.079930075}
# I0409 07:52:56.052192 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.22821812,
#  'Loss/localization_loss': 0.14769623,
#  'Loss/regularization_loss': 0.05996919,
#  'Loss/total_loss': 0.43588355,
#  'learning_rate': 0.079930075}
# INFO:tensorflow:Step 8200 per-step time 1.087s
# I0409 07:54:44.734608 140609851844416 model_lib_v2.py:705] Step 8200 per-step time 1.087s
# INFO:tensorflow:{'Loss/classification_loss': 0.2647288,
#  'Loss/localization_loss': 0.17405389,
#  'Loss/regularization_loss': 0.060194243,
#  'Loss/total_loss': 0.49897695,
#  'learning_rate': 0.079927556}
# I0409 07:54:44.734910 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.2647288,
#  'Loss/localization_loss': 0.17405389,
#  'Loss/regularization_loss': 0.060194243,
#  'Loss/total_loss': 0.49897695,
#  'learning_rate': 0.079927556}
# INFO:tensorflow:Step 8300 per-step time 1.086s
# I0409 07:56:33.334765 140609851844416 model_lib_v2.py:705] Step 8300 per-step time 1.086s
# INFO:tensorflow:{'Loss/classification_loss': 0.3492953,
#  'Loss/localization_loss': 0.21903072,
#  'Loss/regularization_loss': 0.060428753,
#  'Loss/total_loss': 0.6287548,
#  'learning_rate': 0.07992499}
# I0409 07:56:33.335061 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.3492953,
#  'Loss/localization_loss': 0.21903072,
#  'Loss/regularization_loss': 0.060428753,
#  'Loss/total_loss': 0.6287548,
#  'learning_rate': 0.07992499}
# INFO:tensorflow:Step 8400 per-step time 1.087s
# I0409 07:58:22.051402 140609851844416 model_lib_v2.py:705] Step 8400 per-step time 1.087s
# INFO:tensorflow:{'Loss/classification_loss': 0.23974296,
#  'Loss/localization_loss': 0.13221277,
#  'Loss/regularization_loss': 0.060677137,
#  'Loss/total_loss': 0.43263286,
#  'learning_rate': 0.079922386}
# I0409 07:58:22.051745 140609851844416 model_lib_v2.py:708] {'Loss/classification_loss': 0.23974296,
#  'Loss/localization_loss': 0.13221277,
#  'Loss/regularization_loss': 0.060677137,
#  'Loss/total_loss': 0.43263286,
#  'learning_rate': 0.079922386}

# %%
#run model evaluation to obtain performance metrics
#!python /content/models/research/object_detection/model_main_tf2.py \
    #--pipeline_config_path={pipeline_file} \
    #--model_dir={model_dir} \
    #--checkpoint_dir={model_dir} \
#Not yet implemented for EfficientDet

# %%
# %load_ext tensorboard
# %tensorboard --logdir '/content/training/train'

# %% [markdown]
# ## Exporting a Trained Inference Graph
# Still to come for TF2 models, we will be updating this Colab notebook accordingly as the functionality is added.

# %%
#see where our model saved weights
# %ls '/content/training/'

# %%
#run conversion script
import re
import numpy as np

output_directory = '/content/fine_tuned_model'

#place the model weights you would like to export here
last_model_path = '/content/training/'
print(last_model_path)
# !python /content/models/research/object_detection/exporter_main_v2.py \
    --trained_checkpoint_dir {last_model_path} \
    --output_directory {output_directory} \
    --pipeline_config_path {pipeline_file}

# %%
# %ls '/content/fine_tuned_model/saved_model/'

# %% [markdown]
# # Run Inference on Test Images with Custom TensorFlow2 Object Detector

# %%
#downloading test images from Roboflow
#export dataset above with format COCO JSON
#or import your test images via other means. 
# %mkdir /content/test/
# %cd /content/test/
# !curl -L "[YOUR LINK HERE]" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip

# %%
import matplotlib
import matplotlib.pyplot as plt

import io
import scipy.misc
import numpy as np
from six import BytesIO
from PIL import Image, ImageDraw, ImageFont

import tensorflow as tf

from object_detection.utils import label_map_util
from object_detection.utils import config_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.builders import model_builder

# %matplotlib inline

# %%
def load_image_into_numpy_array(path):
  """Load an image from file into a numpy array.

  Puts image into numpy array to feed into tensorflow graph.
  Note that by convention we put it into a numpy array with shape
  (height, width, channels), where channels=3 for RGB.

  Args:
    path: the file path to the image

  Returns:
    uint8 numpy array with shape (img_height, img_width, 3)
  """
  img_data = tf.io.gfile.GFile(path, 'rb').read()
  image = Image.open(BytesIO(img_data))
  (im_width, im_height) = image.size
  return np.array(image.getdata()).reshape(
      (im_height, im_width, 3)).astype(np.uint8)

# %%
# %ls '/content/training/'

# %%
import pathlib

filenames = list(pathlib.Path('/content/training/').glob('*.index'))

filenames.sort()
print(filenames)

#recover our saved model
pipeline_config = pipeline_file
#generally you want to put the last ckpt from training in here
model_dir = str(filenames[-1]).replace('.index','')
configs = config_util.get_configs_from_pipeline_file(pipeline_config)
model_config = configs['model']
detection_model = model_builder.build(
      model_config=model_config, is_training=False)

# Restore checkpoint
ckpt = tf.compat.v2.train.Checkpoint(
      model=detection_model)
ckpt.restore(os.path.join(str(filenames[-1]).replace('.index','')))


def get_model_detection_function(model):
  """Get a tf.function for detection."""

  @tf.function
  def detect_fn(image):
    """Detect objects in image."""

    image, shapes = model.preprocess(image)
    prediction_dict = model.predict(image, shapes)
    detections = model.postprocess(prediction_dict, shapes)

    return detections, prediction_dict, tf.reshape(shapes, [-1])

  return detect_fn

detect_fn = get_model_detection_function(detection_model)

# %%
#map labels for inference decoding
label_map_path = configs['eval_input_config'].label_map_path
label_map = label_map_util.load_labelmap(label_map_path)
categories = label_map_util.convert_label_map_to_categories(
    label_map,
    max_num_classes=label_map_util.get_max_label_map_index(label_map),
    use_display_name=True)
category_index = label_map_util.create_category_index(categories)
label_map_dict = label_map_util.get_label_map_dict(label_map, use_display_name=True)

# %%
#run detector on test image
#it takes a little longer on the first run and then runs at normal speed. 
import random

TEST_IMAGE_PATHS = glob.glob('/content/test/test/*.jpg')
image_path = random.choice(TEST_IMAGE_PATHS)
image_np = load_image_into_numpy_array(image_path)

# Things to try:
# Flip horizontally
# image_np = np.fliplr(image_np).copy()

# Convert image to grayscale
# image_np = np.tile(
#     np.mean(image_np, 2, keepdims=True), (1, 1, 3)).astype(np.uint8)

input_tensor = tf.convert_to_tensor(
    np.expand_dims(image_np, 0), dtype=tf.float32)
detections, predictions_dict, shapes = detect_fn(input_tensor)

label_id_offset = 1
image_np_with_detections = image_np.copy()

viz_utils.visualize_boxes_and_labels_on_image_array(
      image_np_with_detections,
      detections['detection_boxes'][0].numpy(),
      (detections['detection_classes'][0].numpy() + label_id_offset).astype(int),
      detections['detection_scores'][0].numpy(),
      category_index,
      use_normalized_coordinates=True,
      max_boxes_to_draw=200,
      min_score_thresh=.5,
      agnostic_mode=False,
)

plt.figure(figsize=(12,16))
plt.imshow(image_np_with_detections)
plt.show()

# %% [markdown]
# ## Congrats!
#
# Hope you enjoyed this!
#
# --Team [Roboflow](https://roboflow.ai)
