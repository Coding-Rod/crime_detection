# %% [markdown]
# # Metrics

# %% [markdown]
# ## Import dependencies

# %%
import json
import os
import cv2
import matplotlib.pyplot as plt
from tqdm import tqdm
import pandas as pd
import shutil
import math
from sklearn.metrics import classification_report, accuracy_score, f1_score, precision_score, recall_score, roc_curve, auc
import subprocess
import csv
import seaborn as sns

# %% [markdown]
# ## Preprocessing dataset

# %% [markdown]
# ## Load dataset

# %%
DATA_SET_PATH = '/media/rodri/Files/Datasets/Roboflow_v11/Dataset'
DATA_SET_PATH
# Out:
# '/media/rodri/Files/Datasets/Roboflow_v11/Dataset'

# %% [markdown]
# ## Generate annotations json
#
# Headers:
# - path
# - class
# - xmin
# - ymin
# - xmax
# - ymax
#
# Meanings:
# - 0: gun
# - 1: knife

# %%
# Read one file
def read_yolo_file(path):
    with open(path, 'r') as f:
        aux = f.readlines()
        aux = [x.strip().replace(' ',',') for x in aux]
        aux = [x.split(',') for x in aux]
        aux = [[int(x[0]), float(x[1]), float(x[2]), float(x[3]), float(x[4])] for x in aux]
        
        def convert_yolo_format_to_voc(labels, img_width, img_height):
            """ Convert Yolo format to VOC format

            Args:
                x (list): [class, x, y, w, h]
                img_width (int): Image width
                img_height (int): Image height

            Returns:
                list: [class, xmin, ymin, xmax, ymax]
            """
            labels = labels.copy()
            
            x = labels[1] * img_width
            y = labels[2] * img_height
            w = labels[3] * img_width
            h = labels[4] * img_height
            
            xmin = math.floor(x - (w / 2)+1)
            ymin = math.floor(y - (h / 2)+1)
            xmax = math.floor(x + (w / 2)+1)
            ymax = math.floor(y + (h / 2)+1)
            
            return [labels[0], xmin, ymin, xmax, ymax]
        
        def get_image_shape(path):
            img = cv2.imread(path)
            # Getting image path
            try:
                img_path = os.path.dirname(os.path.dirname(path)) + '/images/' + os.path.basename(path).replace('.txt', '.jpg')
                # print(img_path)
                img = cv2.imread(img_path)
                return img.shape[1], img.shape[0]
            finally:
                del img_path
                del img
        
        
        aux = [convert_yolo_format_to_voc(x, *get_image_shape(path)) for x in aux]
        
        # Check if annotations are empty
        if len(aux) == 0:
            aux.append([-1, 0, 0, 0, 0])
            
        [x.insert(0, path) for x in aux]
        
        
        def convert_to_json(x):
            """ Convert to json format
            Consider new meanings:
            - 0: background
            - 1: gun
            - 2: knife

            Args:
                x (list): List of lists with the following format: [path, class, x1, y1, x2, y2]

            Returns:
                _type_: Description of return value
            """        
            
            return {
                'path': x[0],
                'class': x[1]+1,
                'bbox':{
                    'xmin': x[2],
                    'ymin': x[3],
                    'xmax': x[4],
                    'ymax': x[5]
                }
            }
        
        aux = [convert_to_json(x) for x in aux]
        
        # return file name and annotations
        return aux

# Test cases

## No annotations
path = os.path.join(DATA_SET_PATH, 'test/labels/batch_39_jpg.rf.5d98d73855063aadf8a2ddee468b970a.txt')
print("No annotations", end=': ')
print(read_yolo_file(path))

## One annotation
path = os.path.join(DATA_SET_PATH, 'test/labels/00000668_jpg.rf.2031d4cedcf31cd67c48cff1d053eddf.txt')
print("One annotation", end=': ')
print(read_yolo_file(path))

## Multiple annotations
path = os.path.join(DATA_SET_PATH, 'test/labels/batch_40_jpg.rf.d083c576c8cf66569711b7eab35f2df5.txt')
print("Multiple annotations", end=': ')
print(read_yolo_file(path))
# Out:
# No annotations: [{'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/labels/batch_39_jpg.rf.5d98d73855063aadf8a2ddee468b970a.txt', 'class': 0, 'bbox': {'xmin': 0, 'ymin': 0, 'xmax': 0, 'ymax': 0}}]
# One annotation: [{'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/labels/00000668_jpg.rf.2031d4cedcf31cd67c48cff1d053eddf.txt', 'class': 1, 'bbox': {'xmin': 18, 'ymin': 53, 'xmax': 611, 'ymax': 395}}]
# Multiple annotations: [{'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/labels/batch_40_jpg.rf.d083c576c8cf66569711b7eab35f2df5.txt', 'class': 1, 'bbox': {'xmin': 2, 'ymin': 5, 'xmax': 312, 'ymax': 314}}, {'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/labels/batch_40_jpg.rf.d083c576c8cf66569711b7eab35f2df5.txt', 'class': 1, 'bbox': {'xmin': 397, 'ymin': 68, 'xmax': 610, 'ymax': 297}}, {'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/labels/batch_40_jpg.rf.d083c576c8cf66569711b7eab35f2df5.txt', 'class': 1, 'bbox': {'xmin': 8, 'ymin': 322, 'xmax': 314, 'ymax': 629}}, {'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/labels/batch_40_jpg.rf.d083c576c8cf66569711b7eab35f2df5.txt', 'class': 1, 'bbox': {'xmin': 450, 'ymin': 528, 'xmax': 477, 'ymax': 602}}]

# %%
test_labels = [read_yolo_file(os.path.join(DATA_SET_PATH, 'test/labels', x)) for x in tqdm(os.listdir(os.path.join(DATA_SET_PATH, 'test/labels')), desc='Reading test labels')]
# Out:
# Reading test labels: 100%|██████████| 1294/1294 [00:30<00:00, 42.33it/s]

# %%
print(f'Test labels: {len(test_labels)}')
print(f'Last 5 test labels: {json.dumps(test_labels[-5:], indent=4)}')
# Out:
# Test labels: 1294
# Last 5 test labels: [
#     [
#         {
#             "path": "/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/labels/000000295310.txt",
#             "class": 0,
#             "bbox": {
#                 "xmin": 0,
#                 "ymin": 0,
#                 "xmax": 0,
#                 "ymax": 0
#             }
#         }
#     ],
#     [
#         {
#             "path": "/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/labels/000000303738.txt",
#             "class": 0,
#             "bbox": {
#                 "xmin": 0,
#                 "ymin": 0,
#                 "xmax": 0,
#                 "ymax": 0
#             }
#         }
#     ],
#     [
#         {
#             "path": "/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/labels/000000307618.txt",
#             "class": 0,
#             "bbox": {
#                 "xmin": 0,
#                 "ymin": 0,
#                 "xmax": 0,
#                 "ymax": 0
#             }
#         }
#     ],
#     [
#         {
#             "path": "/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/labels/000000308803.txt",
#             "class": 0,
#             "bbox": {
#                 "xmin": 0,
#                 "ymin": 0,
#                 "xmax": 0,
#                 "ymax": 0
#             }
#         }
#     ],
#     [
#         {
#             "path": "/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/labels/000000316397.txt",
#             "class": 0,
#             "bbox": {
#                 "xmin": 0,
#                 "ymin": 0,
#                 "xmax": 0,
#                 "ymax": 0
#             }
#         }
#     ]
# ]

# %% [markdown]
# ## Save annotations as json files

# %%
json.dump(test_labels, open(os.path.join(DATA_SET_PATH, 'test_labels.json'), 'w'))

# %%
del test_labels

# %% [markdown]
# ## Fix json

# %%
test_labels = json.load(open(os.path.join(DATA_SET_PATH, 'test_labels.json'), 'r'))

# %% [markdown]
# ### Convert annotation path from labels to image path

# %%
def convert_label_path_to_image_path(json: list) -> list:
    """ Convert label path to image path

    Args:
        json (list): Json to convert

    Returns:
        list: Converted json
    """
    for item in tqdm(json, desc='Converting label path to image path'):
        for subitem in item:
            subitem['path'] = (subitem['path'].replace('labels', 'images'))[:-3] + 'jpg'
    return json

# Before
print(test_labels[5:])

# Test case
print(convert_label_path_to_image_path(test_labels[5:]))
# Out:
# [[{'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/labels/000000010023.txt', 'class': 0, 'bbox': {'xmin': 0, 'ymin': 0, 'xmax': 0, 'ymax': 0}}], [{'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/labels/000000010701.txt', 'class': 0, 'bbox': {'xmin': 0, 'ymin': 0, 'xmax': 0, 'ymax': 0}}], [{'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/labels/000000022056.txt', 'class': 0, 'bbox': {'xmin': 0, 'ymin': 0, 'xmax': 0, 'ymax': 0}}], [{'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/labels/000000023687.txt', 'class': 0, 'bbox': {'xmin': 0, 'ymin': 0, 'xmax': 0, 'ymax': 0}}], [{'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/labels/000000024414.txt', 'class': 0, 'bbox': {'xmin': 0, 'ymin': 0, 'xmax': 0, 'ymax': 0}}], [{'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/labels/000000031082.txt', 'class': 0, 'bbox': {'xmin': 0, 'ymin': 0, 'xmax': 0, 'ymax': 0}}], [{'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/labels/000000034508.txt', 'class': 0, 'bbox': {'xmin': 0, 'ymin': 0, 'xmax': 0, 'ymax': 0}}], [{'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/labels/000000035395.txt', 'class': 0, 'bbox': {'xmin': 0, 'ymin': 0, 'xmax': 0, 'ymax': 0}}], [{'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/labels/101516494_5781_jpg.rf.90ba3800fa4ed5e25aa2ed5b3dbbc221.txt', 'class': 1, 'bbox': {'xmin': 416, 'ymin': 90, 'xmax': 513, 'ymax': 172}}], [{'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/labels/101712213_1560_jpg.rf.07e2d74050a64c0f5938c13155b694c8.txt', 'class': 1, 'bbox': {'xmin': 93, 'ymin': 120, 'xmax': 292, 'ymax': 386}}, {'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/labels/101712213_1560_jpg.rf.07e2d74050a64c0f5938c13155b694c8.txt', 'class': 1, 'bbox': {'xmin': 254, 'ymin': 71, 'xmax': 358, 'ymax': 418}}], [{'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/labels/101713221_1569_jpg.rf.fefd505eb1c765a52acbaf8efeb29501.txt', 'class': 1, 'bbox': {'xmin': 194, 'ymin': 338, 'xmax': 403, 'ymax': 496}}], [{'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/labels/1017181911_6720_jpg.rf.a923795a401a573b973e11c97a1910e9.txt', 'class': 1, 'bbox': {'xmin': 223, 'ymin': 243, 'xmax': 437, 'ymax': 461}}], [{'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/labels/101721012_420_jpg.rf.5e14164ba1b1b4f5567b04a188322e68.txt', 'class': 1, 'bbox': {'xmin': 151, 'ymin': 270, 'xmax': 599, 'ymax': 603}}], [{'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/labels/1017744_2652_jpg.rf.6aed311ec45424c917afe7bc93d0ea66.txt', 'class': 1, 'bbox': {'xmin': 115, 'ymin': 312, 'xmax': 258, 'ymax': 466}}], [{'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/labels/10178403_3099_jpg.rf.32584ef9831183e8bdac6b8d28148ad9.txt', 'class': 1, 'bbox': {'xmin': 206, 'ymin': 225, 'xmax': 405, 'ymax': 468}}], [{'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/labels/101794753_1545_jpg.rf.458d24633e24b94b1cc6011d9cd8521c.txt', 'class': 1, 'bbox': {'xmin': 62, 'ymin': 182, 'xmax': 551, 'ymax': 640}}], [{'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/labels/10219558_3825_jpg.rf.eaa9351947de68353238f56ba9de5c42.txt', 'class': 1, 'bbox': {'xmin': 13, 'ymin': 86, 'xmax': 138, 'ymax': 303}}], [{'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/labels/102312133_3240_jpg.rf.60e3a0924d732f3cf5af193904434c23.txt', 'class': 1, 'bbox': {'xmin': 287, 'ymin': 294, 'xmax': 319, 'ymax': 382}}], [{'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/labels/1023124758_6429_jpg.rf.5c27c32d4a2b20743084ad358e96ee1d.txt', 'class': 1, 'bbox': {'xmin': 342, 'ymin': 167, 'xmax': 372, 'ymax': 203}}], [{'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/labels/102312630_3582_jpg.rf.b016a6a90b72e63152de39b3cee3b239.txt', 'class': 1, 'bbox': {'xmin': 383, 'ymin': 363, 'xmax': 427, 'ymax': 421}}], [{'path': '/media/rod ...
# Converting label path to image path: 100%|██████████| 1289/1289 [00:00<00:00, 624302.29it/s]
# [[{'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/images/000000010023.jpg', 'class': 0, 'bbox': {'xmin': 0, 'ymin': 0, 'xmax': 0, 'ymax': 0}}], [{'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/images/000000010701.jpg', 'class': 0, 'bbox': {'xmin': 0, 'ymin': 0, 'xmax': 0, 'ymax': 0}}], [{'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/images/000000022056.jpg', 'class': 0, 'bbox': {'xmin': 0, 'ymin': 0, 'xmax': 0, 'ymax': 0}}], [{'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/images/000000023687.jpg', 'class': 0, 'bbox': {'xmin': 0, 'ymin': 0, 'xmax': 0, 'ymax': 0}}], [{'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/images/000000024414.jpg', 'class': 0, 'bbox': {'xmin': 0, 'ymin': 0, 'xmax': 0, 'ymax': 0}}], [{'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/images/000000031082.jpg', 'class': 0, 'bbox': {'xmin': 0, 'ymin': 0, 'xmax': 0, 'ymax': 0}}], [{'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/images/000000034508.jpg', 'class': 0, 'bbox': {'xmin': 0, 'ymin': 0, 'xmax': 0, 'ymax': 0}}], [{'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/images/000000035395.jpg', 'class': 0, 'bbox': {'xmin': 0, 'ymin': 0, 'xmax': 0, 'ymax': 0}}], [{'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/images/101516494_5781_jpg.rf.90ba3800fa4ed5e25aa2ed5b3dbbc221.jpg', 'class': 1, 'bbox': {'xmin': 416, 'ymin': 90, 'xmax': 513, 'ymax': 172}}], [{'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/images/101712213_1560_jpg.rf.07e2d74050a64c0f5938c13155b694c8.jpg', 'class': 1, 'bbox': {'xmin': 93, 'ymin': 120, 'xmax': 292, 'ymax': 386}}, {'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/images/101712213_1560_jpg.rf.07e2d74050a64c0f5938c13155b694c8.jpg', 'class': 1, 'bbox': {'xmin': 254, 'ymin': 71, 'xmax': 358, 'ymax': 418}}], [{'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/images/101713221_1569_jpg.rf.fefd505eb1c765a52acbaf8efeb29501.jpg', 'class': 1, 'bbox': {'xmin': 194, 'ymin': 338, 'xmax': 403, 'ymax': 496}}], [{'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/images/1017181911_6720_jpg.rf.a923795a401a573b973e11c97a1910e9.jpg', 'class': 1, 'bbox': {'xmin': 223, 'ymin': 243, 'xmax': 437, 'ymax': 461}}], [{'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/images/101721012_420_jpg.rf.5e14164ba1b1b4f5567b04a188322e68.jpg', 'class': 1, 'bbox': {'xmin': 151, 'ymin': 270, 'xmax': 599, 'ymax': 603}}], [{'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/images/1017744_2652_jpg.rf.6aed311ec45424c917afe7bc93d0ea66.jpg', 'class': 1, 'bbox': {'xmin': 115, 'ymin': 312, 'xmax': 258, 'ymax': 466}}], [{'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/images/10178403_3099_jpg.rf.32584ef9831183e8bdac6b8d28148ad9.jpg', 'class': 1, 'bbox': {'xmin': 206, 'ymin': 225, 'xmax': 405, 'ymax': 468}}], [{'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/images/101794753_1545_jpg.rf.458d24633e24b94b1cc6011d9cd8521c.jpg', 'class': 1, 'bbox': {'xmin': 62, 'ymin': 182, 'xmax': 551, 'ymax': 640}}], [{'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/images/10219558_3825_jpg.rf.eaa9351947de68353238f56ba9de5c42.jpg', 'class': 1, 'bbox': {'xmin': 13, 'ymin': 86, 'xmax': 138, 'ymax': 303}}], [{'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/images/102312133_3240_jpg.rf.60e3a0924d732f3cf5af193904434c23.jpg', 'class': 1, 'bbox': {'xmin': 287, 'ymin': 294, 'xmax': 319, 'ymax': 382}}], [{'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/images/1023124758_6429_jpg.rf.5c27c32d4a2b20743084ad358e96ee1d.jpg', 'class': 1, 'bbox': {'xmin': 342, 'ymin': 167, 'xmax': 372, 'ymax': 203}}], [{'path': '/media/rodri/Files/Datasets/Roboflow_v11/Dataset/test/images/102312630_3582_jpg.rf.b016a6a90b72e63152de39b3cee3b239.jpg', 'class': 1, 'bbox': {'xmin': 383, 'ymin': 363, 'xmax': 427, 'ymax': 421}}], [{'path': '/media/rod ...

# %%
test_labels = convert_label_path_to_image_path(test_labels)
# Out:
# Converting label path to image path: 100%|██████████| 1294/1294 [00:00<00:00, 586749.12it/s]

# %% [markdown]
# ### Save results as json files on metrics folder

# %%
json.dump(test_labels, open(os.path.join(DATA_SET_PATH, 'test_labels.json'), 'w'))
